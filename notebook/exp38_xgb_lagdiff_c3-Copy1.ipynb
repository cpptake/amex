# %% [markdown]
# # exp37
#
# lag_diffのXGB
#
#
# https://www.kaggle.com/code/ragnar123/amex-lgbm-dart-cv-0-7977

# %%
# ====================================================
# Library
# ====================================================
import gc
import warnings
warnings.filterwarnings('ignore')
import scipy as sp
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
from tqdm.auto import tqdm
import itertools

import lightgbm as lgb
import xgboost as xgb

# %%
print(xgb.__version__)
# Out:
# 1.5.0

# %%
# ====================================================
# Get the difference
# ====================================================
def get_difference(data, num_features):
    df1 = []
    customer_ids = []
    for customer_id, df in tqdm(data.groupby(['customer_ID'])):
        # Get the differences
        diff_df1 = df[num_features].diff(1).iloc[[-1]].values.astype(np.float32)
        # Append to lists
        df1.append(diff_df1)
        customer_ids.append(customer_id)
    # Concatenate
    df1 = np.concatenate(df1, axis = 0)
    # Transform to dataframe
    df1 = pd.DataFrame(df1, columns = [col + '_diff1' for col in df[num_features].columns])
    # Add customer id
    df1['customer_ID'] = customer_ids
    return df1

# ====================================================
# Read & preprocess data and save it to disk
# ====================================================
def read_preprocess_data():
    train = pd.read_parquet('/content/data/train.parquet')
    features = train.drop(['customer_ID', 'S_2'], axis = 1).columns.to_list()
    cat_features = [
        "B_30",
        "B_38",
        "D_114",
        "D_116",
        "D_117",
        "D_120",
        "D_126",
        "D_63",
        "D_64",
        "D_66",
        "D_68",
    ]
    num_features = [col for col in features if col not in cat_features]
    print('Starting training feature engineer...')
    train_num_agg = train.groupby("customer_ID")[num_features].agg(['mean', 'std', 'min', 'max', 'last'])
    train_num_agg.columns = ['_'.join(x) for x in train_num_agg.columns]
    train_num_agg.reset_index(inplace = True)
    train_cat_agg = train.groupby("customer_ID")[cat_features].agg(['count', 'last', 'nunique'])
    train_cat_agg.columns = ['_'.join(x) for x in train_cat_agg.columns]
    train_cat_agg.reset_index(inplace = True)
    train_labels = pd.read_csv('../input/amex-default-prediction/train_labels.csv')
    # Transform float64 columns to float32
    cols = list(train_num_agg.dtypes[train_num_agg.dtypes == 'float64'].index)
    for col in tqdm(cols):
        train_num_agg[col] = train_num_agg[col].astype(np.float32)
    # Transform int64 columns to int32
    cols = list(train_cat_agg.dtypes[train_cat_agg.dtypes == 'int64'].index)
    for col in tqdm(cols):
        train_cat_agg[col] = train_cat_agg[col].astype(np.int32)
    # Get the difference
    train_diff = get_difference(train, num_features)
    train = train_num_agg.merge(train_cat_agg, how = 'inner', on = 'customer_ID').merge(train_diff, how = 'inner', on = 'customer_ID').merge(train_labels, how = 'inner', on = 'customer_ID')
    del train_num_agg, train_cat_agg, train_diff
    gc.collect()
    test = pd.read_parquet('../input/amex-fe/test_fe.parquet')
    print('Starting test feature engineer...')
    test_num_agg = test.groupby("customer_ID")[num_features].agg(['mean', 'std', 'min', 'max', 'last'])
    test_num_agg.columns = ['_'.join(x) for x in test_num_agg.columns]
    test_num_agg.reset_index(inplace = True)
    test_cat_agg = test.groupby("customer_ID")[cat_features].agg(['count', 'last', 'nunique'])
    test_cat_agg.columns = ['_'.join(x) for x in test_cat_agg.columns]
    test_cat_agg.reset_index(inplace = True)
    # Transform float64 columns to float32
    cols = list(test_num_agg.dtypes[test_num_agg.dtypes == 'float64'].index)
    for col in tqdm(cols):
        test_num_agg[col] = test_num_agg[col].astype(np.float32)
    # Transform int64 columns to int32
    cols = list(test_cat_agg.dtypes[test_cat_agg.dtypes == 'int64'].index)
    for col in tqdm(cols):
        test_cat_agg[col] = test_cat_agg[col].astype(np.int32)
    # Get the difference
    test_diff = get_difference(test, num_features)
    test = test_num_agg.merge(test_cat_agg, how = 'inner', on = 'customer_ID').merge(test_diff, how = 'inner', on = 'customer_ID')
    del test_num_agg, test_cat_agg, test_diff
    gc.collect()
    # Save files to disk
    train.to_parquet('../input/amex-fe/train_fe.parquet')
    test.to_parquet('../input/amex-fe/test_fe.parquet')

# Read & Preprocess Data
read_preprocess_data()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20612\217815574.py in <module>
#      86
#      87 # Read & Preprocess Data
# ---> 88 read_preprocess_data()
#
# ~\AppData\Local\Temp\ipykernel_20612\217815574.py in read_preprocess_data()
#      23 # ====================================================
#      24 def read_preprocess_data():
# ---> 25     train = pd.read_parquet('/content/data/train.parquet')
#      26     features = train.drop(['customer_ID', 'S_2'], axis = 1).columns.to_list()
#      27     cat_features = [
#
# ~\anaconda3\envs\amex\lib\site-packages\pandas\io\parquet.py in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, **kwargs)
#     498         storage_options=storage_options,
#     499         use_nullable_dtypes=use_nullable_dtypes,
# --> 500         **kwargs,
#     501     )
#
# ~\anaconda3\envs\amex\lib\site-packages\pandas\io\parquet.py in read(self, path, columns, use_nullable_dtypes, storage_options, **kwargs)
#     234             kwargs.pop("filesystem", None),
#     235             storage_options=storage_options,
# --> 236             mode="rb",
#     237         )
#     238         try:
#
# ~\anaconda3\envs\amex\lib\site-packages\pandas\io\parquet.py in _get_path_or_handle(path, fs, storage_options, mode, is_dir)
#     100         # this branch is used for example when reading from non-fsspec URLs
#     101         handles = get_handle(
# --> 102             path_or_handle, mode, is_text=False, storage_options=storage_options
#     103         )
#     104         fs = None
#
# ~\anaconda3\envs\amex\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     709         else:
#     710             # Binary mode
# --> 711             handle = open(handle, ioargs.mode)
#     712         handles.append(handle)
#     713
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/data/train.parquet'

# %% [markdown]
# # Training & Inference

# %%
# ====================================================
# Library
# ====================================================
import os
import gc
import warnings
warnings.filterwarnings('ignore')
import random
import scipy as sp
import numpy as np
import pandas as pd
import joblib
import itertools
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
from tqdm.auto import tqdm
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.preprocessing import LabelEncoder
import lightgbm as lgb
from itertools import combinations

import pickle

# ====================================================
# Configurations
# ====================================================
class CFG:
    
    
    # input_dir = '../feature/exp35_lagdiff/'
    input_dir = '../feature/exp03_amex-fe/'
    output_dir = '../output/exp38_xgb_lagdiff_c3/'
    seed = 42
    n_folds = 5
    target = 'target'
    boosting_type = 'dart'
    metric = 'binary_logloss'
    model = "xgb"
    ver = "exp37"

# ====================================================
# Seed everything
# ====================================================
def seed_everything(seed):
    random.seed(seed)
    np.random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)

# ====================================================
# Read data
# ====================================================
# def read_data():
#     train = pd.read_parquet(CFG.input_dir + 'train_diff.parquet')
#     test = pd.read_parquet(CFG.input_dir + 'test_diff.parquet')
#     return train, test

def read_data():
    train = pd.read_parquet(CFG.input_dir + 'train_fe_plus_plus.parquet')
    test = pd.read_parquet(CFG.input_dir + 'test_fe_plus_plus.parquet')
    return train, test

# ====================================================
# Amex metric
# ====================================================
def amex_metric(y_true, y_pred):
    labels = np.transpose(np.array([y_true, y_pred]))
    labels = labels[labels[:, 1].argsort()[::-1]]
    weights = np.where(labels[:,0]==0, 20, 1)
    cut_vals = labels[np.cumsum(weights) <= int(0.04 * np.sum(weights))]
    top_four = np.sum(cut_vals[:,0]) / np.sum(labels[:,0])
    gini = [0,0]
    for i in [1,0]:
        labels = np.transpose(np.array([y_true, y_pred]))
        labels = labels[labels[:, i].argsort()[::-1]]
        weight = np.where(labels[:,0]==0, 20, 1)
        weight_random = np.cumsum(weight / np.sum(weight))
        total_pos = np.sum(labels[:, 0] *  weight)
        cum_pos_found = np.cumsum(labels[:, 0] * weight)
        lorentz = cum_pos_found / total_pos
        gini[i] = np.sum((lorentz - weight_random) * weight)
    return 0.5 * (gini[1]/gini[0] + top_four)

# ====================================================
# LGBM amex metric
# ====================================================
def lgb_amex_metric(y_pred, y_true):
    y_true = y_true.get_label()
    return 'amex_metric', amex_metric(y_true, y_pred), True

# %%
seed_everything(CFG.seed)

train = pd.read_parquet('../feature/exp35_lagdiff/train_lagdiff.parquet')
test = pd.read_parquet('../feature/exp35_lagdiff/test_lagdiff.parquet')

# train, test = read_data()

train_c3 = pd.read_pickle('../feature/exp18_4_tsfresh/train_c3.pkl')
test_c3 = pd.read_pickle('../feature/exp18_4_tsfresh/test_c3.pkl')

train = train.merge(train_c3,on = "customer_ID",how = "left")
test = test.merge(test_c3,on = "customer_ID",how = "left")

del train_c3,test_c3
gc.collect

print(train.shape)
print(test.shape)
# Out:
# (458913, 2013)
# (924621, 2012)

# %%
def xgb_amex(y_pred, y_true):
    return 'amex', amex_metric_np(y_pred,y_true.get_label())


def amex_metric_np(preds: np.ndarray, target: np.ndarray) -> float:
    indices = np.argsort(preds)[::-1]
    preds, target = preds[indices], target[indices]

    weight = 20.0 - target * 19.0
    cum_norm_weight = (weight / weight.sum()).cumsum()
    four_pct_mask = cum_norm_weight <= 0.04
    d = np.sum(target[four_pct_mask]) / np.sum(target)

    weighted_target = target * weight
    lorentz = (weighted_target / weighted_target.sum()).cumsum()
    gini = ((lorentz - cum_norm_weight) * weight).sum()

    n_pos = np.sum(target)
    n_neg = target.shape[0] - n_pos
    gini_max = 10 * n_neg * (n_pos + 20 * n_neg - 19) / (n_pos + 20 * n_neg)

    g = gini / gini_max
    return 0.5 * (g + d)

# %%
train.fillna(value=0, inplace=True)
test.fillna(value=0, inplace=True)

## infを含むデータを外れ値（－１００００）に置換
train = train.replace([np.inf, -np.inf],0)
test = test.replace([np.inf, -np.inf],0)

cat_features = [
    "B_30",
    "B_38",
    "D_114",
    "D_116",
    "D_117",
    "D_120",
    "D_126",
    "D_63",
    "D_64",
    "D_66",
    "D_68"
]

# kmeans_list = ["kmeans pred 2","kmeans pred 3","kmeans pred 4"]

cat_features = [f"{cf}_last" for cf in cat_features]
# cat_features.extend(kmeans_list)

# for cat_col in cat_features:
# #     print(cat_col)
#     encoder = LabelEncoder()
#     train[cat_col] = encoder.fit_transform(train[cat_col])
#     test[cat_col] = encoder.transform(test[cat_col])


features = [col for col in train.columns if col not in ['customer_ID', CFG.target]]

xgb_parameters={
        'max_depth': 7,
        'eta': 0.03,
        'subsample': 0.88,
        'colsample_bytree': 0.5,
        'objective': 'binary:logistic',
        'tree_method': 'hist',#gpu_hist
        # 'predictor': 'gpu_predictor',
        'random_state': 42,
        'gamma': 1.5,
        'min_child_weight': 8,
        'lambda': 70,
    }

# Create a numpy array to store test predictions
test_predictions = np.zeros(len(test))
# Create a numpy array to store out of folds predictions
oof_predictions = np.zeros(len(train))

cids = []
tr_target = []

# epoch = [10000,7500,7500,8500,10500]

kfold = StratifiedKFold(n_splits = CFG.n_folds, shuffle = True, random_state = CFG.seed)
for fold, (trn_ind, val_ind) in enumerate(kfold.split(train, train[CFG.target])):
    print(' ')
    print('-'*50)
    print(f'Training fold {fold} with {len(features)} features...')
    x_train, x_val = train[features].iloc[trn_ind], train[features].iloc[val_ind]
    y_train, y_val = train[CFG.target].iloc[trn_ind], train[CFG.target].iloc[val_ind]
    
    dtrain = xgb.DMatrix(data=x_train, label=y_train)
    dvalid = xgb.DMatrix(data=x_val, label=y_val)
    dtest = xgb.DMatrix(data=test[features])
    
#     des = DartEarlyStopping("valid_1", CFG.metric, 1000)
  
    model = xgb.train(
            xgb_parameters,
            dtrain=dtrain,
            num_boost_round=9999,#9999
            evals=[(dtrain, "train"), (dvalid, "valid")],
            early_stopping_rounds=500,
            feval=xgb_amex,
            maximize=True,
            verbose_eval=100
        )
    
#     model = lgb.train(
#         params = params,
#         train_set = lgb_train,
#         num_boost_round = epoch[fold],#10500
#         valid_sets = [lgb_train, lgb_valid],
#         early_stopping_rounds = 1500,
# #         eval_metric=[lgb_amex_metric],
#         verbose_eval = 500,
#         feval = lgb_amex_metric
#         )
    
    # Save best model
    model.save_model(f'{CFG.output_dir}{CFG.model}_{CFG.ver}_{CFG.boosting_type}_fold{fold}_seed{CFG.seed}.xgb')
#     joblib.dump(model, f'{CFG.output_dir}lgbm_{CFG.boosting_type}_fold{fold}_seed{CFG.seed}.pkl')
    # Predict validation
    val_pred = model.predict(dvalid)
    # Add to out of folds array
    oof_predictions[val_ind] = val_pred
    
    cids.extend(train["customer_ID"].loc[val_ind])
    tr_target.extend(train["target"].loc[val_ind])
    
    # Predict the test set
    test_pred = model.predict(dtest)
    test_predictions += test_pred / CFG.n_folds
    # Compute fold metric
    score = amex_metric(y_val, val_pred)
    print(f'Our fold {fold} CV score is {score}')
    del x_train, x_val, y_train, y_val, dtrain, dtest ,dvalid
    gc.collect()
    
# Compute out of folds metric
score = amex_metric(train[CFG.target], oof_predictions)
print(f'Our out of folds CV score is {score}')


# Create a dataframe to store test prediction
test_df = pd.DataFrame({'customer_ID': test['customer_ID'], 'prediction': test_predictions})
# test_df.to_csv(f'{CFG.output_dir}test_{CFG.model}_{score}_baseline_{CFG.n_folds}fold_seed{CFG.seed}.csv', index = False)
test_df.to_csv(f'{CFG.output_dir}test_{CFG.ver}_{CFG.model}_{score}_{CFG.n_folds}fold_seed{CFG.seed}.csv', index = False)


dic_oof = {
    "customer_ID":cids,
    "target":tr_target,
    "tabnet_oot":oof_predictions
}

# Create a dataframe to store out of folds predictions
oof_df = pd.DataFrame(dic_oof)
# oof_df = pd.DataFrame({'customer_ID': train['customer_ID'], 'target': train[CFG.target], 'prediction': oof_predictions})
oof_df.to_csv(f'{CFG.output_dir}oof_{CFG.ver}_{CFG.model}_{score}_{CFG.n_folds}fold_seed{CFG.seed}.csv', index = False)


# # Create a dataframe to store out of folds predictions
# oof_df = pd.DataFrame({'customer_ID': train['customer_ID'], 'target': train[CFG.target], 'prediction': oof_predictions})
# oof_df.to_csv(f'../output/Amex LGBM Dart CV 0.7977/oof_lgbm_{CFG.boosting_type}_baseline_{CFG.n_folds}fold_seed{CFG.seed}.csv', index = False)


# # Create a dataframe to store test prediction
# test_df = pd.DataFrame({'customer_ID': test['customer_ID'], 'prediction': test_predictions})
# test_df.to_csv(f'../output/Amex LGBM Dart CV 0.7977/test_lgbm_{CFG.boosting_type}_baseline_{CFG.n_folds}fold_seed{CFG.seed}.csv', index = False)
# Out:
#
# --------------------------------------------------
# Training fold 0 with 2011 features...
# [00:46:06] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0]	train-logloss:0.67375	train-amex:0.70812	valid-logloss:0.67378	valid-amex:0.70623
# [100]	train-logloss:0.24229	train-amex:0.77930	valid-logloss:0.24661	valid-amex:0.77142
# [200]	train-logloss:0.21671	train-amex:0.79748	valid-logloss:0.22525	valid-amex:0.78380
# [300]	train-logloss:0.20721	train-amex:0.81165	valid-logloss:0.22026	valid-amex:0.79036
# [400]	train-logloss:0.20051	train-amex:0.82220	valid-logloss:0.21797	valid-amex:0.79350
# [500]	train-logloss:0.19542	train-amex:0.83048	valid-logloss:0.21670	valid-amex:0.79498
# [600]	train-logloss:0.19098	train-amex:0.83781	valid-logloss:0.21587	valid-amex:0.79648
# [700]	train-logloss:0.18708	train-amex:0.84468	valid-logloss:0.21526	valid-amex:0.79715
# [800]	train-logloss:0.18330	train-amex:0.85148	valid-logloss:0.21482	valid-amex:0.79793
# [900]	train-logloss:0.17963	train-amex:0.85805	valid-logloss:0.21452	valid-amex:0.79905
# [1000]	train-logloss:0.17607	train-amex:0.86454	valid-logloss:0.21430	valid-amex:0.79938
# [1100]	train-logloss:0.17273	train-amex:0.87096	valid-logloss:0.21409	valid-amex:0.79952
# [1200]	train-logloss:0.16964	train-amex:0.87663	valid-logloss:0.21394	valid-amex:0.79913
# [1300]	train-logloss:0.16633	train-amex:0.88262	valid-logloss:0.21382	valid-amex:0.79972
# [1400]	train-logloss:0.16296	train-amex:0.88826	valid-logloss:0.21373	valid-amex:0.80011
# [1500]	train-logloss:0.15996	train-amex:0.89394	valid-logloss:0.21371	valid-amex:0.79965
# [1600]	train-logloss:0.15689	train-amex:0.89937	valid-logloss:0.21363	valid-amex:0.79978
# [1700]	train-logloss:0.15399	train-amex:0.90409	valid-logloss:0.21359	valid-amex:0.80010
# [1800]	train-logloss:0.15099	train-amex:0.90939	valid-logloss:0.21360	valid-amex:0.79938
# [1900]	train-logloss:0.14822	train-amex:0.91424	valid-logloss:0.21356	valid-amex:0.79913
# [2000]	train-logloss:0.14539	train-amex:0.91909	valid-logloss:0.21357	valid-amex:0.79878
# [2100]	train-logloss:0.14283	train-amex:0.92353	valid-logloss:0.21356	valid-amex:0.79917
# [2200]	train-logloss:0.14019	train-amex:0.92774	valid-logloss:0.21348	valid-amex:0.79977
# [2205]	train-logloss:0.14005	train-amex:0.92795	valid-logloss:0.21348	valid-amex:0.79946
# Our fold 0 CV score is 0.7993021808162047
#
# --------------------------------------------------
# Training fold 1 with 2011 features...
# [01:48:43] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0]	train-logloss:0.67371	train-amex:0.70724	valid-logloss:0.67381	valid-amex:0.70215
# [100]	train-logloss:0.24167	train-amex:0.78051	valid-logloss:0.24845	valid-amex:0.76510
# [200]	train-logloss:0.21619	train-amex:0.79860	valid-logloss:0.22799	valid-amex:0.77604
# [300]	train-logloss:0.20651	train-amex:0.81279	valid-logloss:0.22331	valid-amex:0.78226
# [400]	train-logloss:0.20008	train-amex:0.82284	valid-logloss:0.22121	valid-amex:0.78518
# [500]	train-logloss:0.19495	train-amex:0.83182	valid-logloss:0.22000	valid-amex:0.78582
# [600]	train-logloss:0.19018	train-amex:0.84003	valid-logloss:0.21926	valid-amex:0.78777
# [700]	train-logloss:0.18620	train-amex:0.84700	valid-logloss:0.21881	valid-amex:0.78869
# [800]	train-logloss:0.18236	train-amex:0.85376	valid-logloss:0.21846	valid-amex:0.78975
# [900]	train-logloss:0.17860	train-amex:0.86050	valid-logloss:0.21819	valid-amex:0.79027
# [1000]	train-logloss:0.17499	train-amex:0.86687	valid-logloss:0.21798	valid-amex:0.78963
# [1100]	train-logloss:0.17167	train-amex:0.87286	valid-logloss:0.21779	valid-amex:0.79073
# [1200]	train-logloss:0.16845	train-amex:0.87838	valid-logloss:0.21768	valid-amex:0.79067
# [1300]	train-logloss:0.16519	train-amex:0.88453	valid-logloss:0.21757	valid-amex:0.79133
# [1400]	train-logloss:0.16188	train-amex:0.89032	valid-logloss:0.21754	valid-amex:0.79162
# [1500]	train-logloss:0.15870	train-amex:0.89586	valid-logloss:0.21750	valid-amex:0.79097
# [1600]	train-logloss:0.15558	train-amex:0.90105	valid-logloss:0.21747	valid-amex:0.79128
# [1700]	train-logloss:0.15262	train-amex:0.90655	valid-logloss:0.21741	valid-amex:0.79096
# [1800]	train-logloss:0.14976	train-amex:0.91128	valid-logloss:0.21738	valid-amex:0.79060
# [1900]	train-logloss:0.14706	train-amex:0.91611	valid-logloss:0.21740	valid-amex:0.79114
# [1913]	train-logloss:0.14674	train-amex:0.91661	valid-logloss:0.21740	valid-amex:0.79142
# Our fold 1 CV score is 0.7911779198191169
#
# --------------------------------------------------
# Training fold 2 with 2011 features...
# [02:42:53] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0]	train-logloss:0.67370	train-amex:0.70907	valid-logloss:0.67381	valid-amex:0.70345
# [100]	train-logloss:0.24174	train-amex:0.77983	valid-logloss:0.24887	valid-amex:0.76995
# [200]	train-logloss:0.21623	train-amex:0.79828	valid-logloss:0.22797	valid-amex:0.78052
# [300]	train-logloss:0.20683	train-amex:0.81246	valid-logloss:0.22308	valid-amex:0.78731
# [400]	train-logloss:0.20022	train-amex:0.82274	valid-logloss:0.22069	valid-amex:0.79151
# [500]	train-logloss:0.19488	train-amex:0.83158	valid-logloss:0.21943	valid-amex:0.79259
# [600]	train-logloss:0.19013	train-amex:0.83961	valid-logloss:0.21861	valid-amex:0.79315
# [700]	train-logloss:0.18611	train-amex:0.84665	valid-logloss:0.21812	valid-amex:0.79412
# [800]	train-logloss:0.18225	train-amex:0.85407	valid-logloss:0.21778	valid-amex:0.79477
# [900]	train-logloss:0.17841	train-amex:0.86106	valid-logloss:0.21747	valid-amex:0.79513
# [1000]	train-logloss:0.17477	train-amex:0.86769	valid-logloss:0.21725	valid-amex:0.79541
# [1100]	train-logloss:0.17134	train-amex:0.87388	valid-logloss:0.21711	valid-amex:0.79605
# [1200]	train-logloss:0.16795	train-amex:0.87986	valid-logloss:0.21700	valid-amex:0.79620
# [1300]	train-logloss:0.16467	train-amex:0.88511	valid-logloss:0.21687	valid-amex:0.79621
# [1400]	train-logloss:0.16164	train-amex:0.89073	valid-logloss:0.21681	valid-amex:0.79623
# [1500]	train-logloss:0.15877	train-amex:0.89587	valid-logloss:0.21677	valid-amex:0.79610
# [1600]	train-logloss:0.15572	train-amex:0.90123	valid-logloss:0.21673	valid-amex:0.79614
# [1700]	train-logloss:0.15282	train-amex:0.90612	valid-logloss:0.21670	valid-amex:0.79628
# [1800]	train-logloss:0.14993	train-amex:0.91091	valid-logloss:0.21670	valid-amex:0.79658
# [1900]	train-logloss:0.14732	train-amex:0.91511	valid-logloss:0.21670	valid-amex:0.79686
# [2000]	train-logloss:0.14444	train-amex:0.91994	valid-logloss:0.21667	valid-amex:0.79679
# [2100]	train-logloss:0.14184	train-amex:0.92399	valid-logloss:0.21664	valid-amex:0.79654
# [2200]	train-logloss:0.13923	train-amex:0.92844	valid-logloss:0.21666	valid-amex:0.79616
# [2300]	train-logloss:0.13656	train-amex:0.93252	valid-logloss:0.21666	valid-amex:0.79653
# [2369]	train-logloss:0.13486	train-amex:0.93508	valid-logloss:0.21668	valid-amex:0.79621
# Our fold 2 CV score is 0.7959712961064116
#
# --------------------------------------------------
# Training fold 3 with 2011 features...
# [03:49:30] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0]	train-logloss:0.67370	train-amex:0.70996	valid-logloss:0.67391	valid-amex:0.69728
# [100]	train-logloss:0.24132	train-amex:0.78045	valid-logloss:0.25001	valid-amex:0.76372
# [200]	train-logloss:0.21573	train-amex:0.79936	valid-logloss:0.22938	valid-amex:0.77451
# [300]	train-logloss:0.20638	train-amex:0.81380	valid-logloss:0.22465	valid-amex:0.78045
# [400]	train-logloss:0.19976	train-amex:0.82428	valid-logloss:0.22232	valid-amex:0.78329
# [500]	train-logloss:0.19442	train-amex:0.83249	valid-logloss:0.22107	valid-amex:0.78489
# [600]	train-logloss:0.18975	train-amex:0.84051	valid-logloss:0.22027	valid-amex:0.78617
# [700]	train-logloss:0.18572	train-amex:0.84769	valid-logloss:0.21974	valid-amex:0.78706
# [800]	train-logloss:0.18196	train-amex:0.85448	valid-logloss:0.21934	valid-amex:0.78736
# [900]	train-logloss:0.17791	train-amex:0.86157	valid-logloss:0.21906	valid-amex:0.78774
# [1000]	train-logloss:0.17429	train-amex:0.86791	valid-logloss:0.21887	valid-amex:0.78846
# [1100]	train-logloss:0.17087	train-amex:0.87413	valid-logloss:0.21871	valid-amex:0.78823
# [1200]	train-logloss:0.16752	train-amex:0.88026	valid-logloss:0.21856	valid-amex:0.78869
# [1300]	train-logloss:0.16425	train-amex:0.88595	valid-logloss:0.21847	valid-amex:0.78904
# [1400]	train-logloss:0.16106	train-amex:0.89162	valid-logloss:0.21838	valid-amex:0.78938
# [1500]	train-logloss:0.15812	train-amex:0.89692	valid-logloss:0.21832	valid-amex:0.78900
# [1600]	train-logloss:0.15525	train-amex:0.90239	valid-logloss:0.21830	valid-amex:0.78919
# [1700]	train-logloss:0.15227	train-amex:0.90756	valid-logloss:0.21826	valid-amex:0.78904
# [1800]	train-logloss:0.14947	train-amex:0.91236	valid-logloss:0.21822	valid-amex:0.78952
# [1900]	train-logloss:0.14681	train-amex:0.91690	valid-logloss:0.21821	valid-amex:0.78928
# [2000]	train-logloss:0.14398	train-amex:0.92138	valid-logloss:0.21818	valid-amex:0.79023
# [2100]	train-logloss:0.14137	train-amex:0.92550	valid-logloss:0.21814	valid-amex:0.78966
# [2200]	train-logloss:0.13862	train-amex:0.93008	valid-logloss:0.21813	valid-amex:0.78974
# [2300]	train-logloss:0.13595	train-amex:0.93412	valid-logloss:0.21819	valid-amex:0.78977
# [2400]	train-logloss:0.13349	train-amex:0.93788	valid-logloss:0.21821	valid-amex:0.78986
# [2500]	train-logloss:0.13115	train-amex:0.94122	valid-logloss:0.21823	valid-amex:0.78989
# [2600]	train-logloss:0.12865	train-amex:0.94465	valid-logloss:0.21824	valid-amex:0.79003
# [2700]	train-logloss:0.12629	train-amex:0.94805	valid-logloss:0.21827	valid-amex:0.79056
# [2800]	train-logloss:0.12397	train-amex:0.95122	valid-logloss:0.21832	valid-amex:0.79116
# [2900]	train-logloss:0.12171	train-amex:0.95428	valid-logloss:0.21837	valid-amex:0.79057
# [3000]	train-logloss:0.11968	train-amex:0.95668	valid-logloss:0.21842	valid-amex:0.79070
# [3100]	train-logloss:0.11742	train-amex:0.95959	valid-logloss:0.21850	valid-amex:0.79018
# [3200]	train-logloss:0.11524	train-amex:0.96210	valid-logloss:0.21860	valid-amex:0.79078
# [3300]	train-logloss:0.11312	train-amex:0.96463	valid-logloss:0.21866	valid-amex:0.79133
# [3400]	train-logloss:0.11125	train-amex:0.96657	valid-logloss:0.21867	valid-amex:0.79090
# [3500]	train-logloss:0.10922	train-amex:0.96883	valid-logloss:0.21875	valid-amex:0.79150
# [3600]	train-logloss:0.10728	train-amex:0.97082	valid-logloss:0.21882	valid-amex:0.79100
# [3700]	train-logloss:0.10548	train-amex:0.97249	valid-logloss:0.21890	valid-amex:0.79179
# [3800]	train-logloss:0.10369	train-amex:0.97413	valid-logloss:0.21899	valid-amex:0.79160
# [3900]	train-logloss:0.10198	train-amex:0.97576	valid-logloss:0.21910	valid-amex:0.79150
# [4000]	train-logloss:0.10031	train-amex:0.97723	valid-logloss:0.21920	valid-amex:0.79170
# [4100]	train-logloss:0.09863	train-amex:0.97858	valid-logloss:0.21929	valid-amex:0.79150
# [4200]	train-logloss:0.09692	train-amex:0.98000	valid-logloss:0.21940	valid-amex:0.79189
# [4216]	train-logloss:0.09670	train-amex:0.98018	valid-logloss:0.21940	valid-amex:0.79192
# Our fold 3 CV score is 0.7917457033114773
#
# --------------------------------------------------
# Training fold 4 with 2011 features...
# [05:47:19] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0]	train-logloss:0.67367	train-amex:0.70703	valid-logloss:0.67383	valid-amex:0.70524
# [100]	train-logloss:0.24209	train-amex:0.77938	valid-logloss:0.24752	valid-amex:0.77009
# [200]	train-logloss:0.21654	train-amex:0.79785	valid-logloss:0.22631	valid-amex:0.78219
# [300]	train-logloss:0.20689	train-amex:0.81219	valid-logloss:0.22139	valid-amex:0.78694
# [400]	train-logloss:0.20053	train-amex:0.82223	valid-logloss:0.21913	valid-amex:0.78844
# [500]	train-logloss:0.19507	train-amex:0.83121	valid-logloss:0.21777	valid-amex:0.79070
# [600]	train-logloss:0.19059	train-amex:0.83935	valid-logloss:0.21697	valid-amex:0.79234
# [700]	train-logloss:0.18662	train-amex:0.84614	valid-logloss:0.21641	valid-amex:0.79211
# [800]	train-logloss:0.18297	train-amex:0.85222	valid-logloss:0.21602	valid-amex:0.79344
# [900]	train-logloss:0.17932	train-amex:0.85873	valid-logloss:0.21569	valid-amex:0.79391
# [1000]	train-logloss:0.17562	train-amex:0.86531	valid-logloss:0.21544	valid-amex:0.79404
# [1100]	train-logloss:0.17214	train-amex:0.87157	valid-logloss:0.21528	valid-amex:0.79418
# [1200]	train-logloss:0.16903	train-amex:0.87732	valid-logloss:0.21509	valid-amex:0.79469
# [1300]	train-logloss:0.16584	train-amex:0.88326	valid-logloss:0.21498	valid-amex:0.79498
# [1400]	train-logloss:0.16257	train-amex:0.88895	valid-logloss:0.21490	valid-amex:0.79551
# [1500]	train-logloss:0.15937	train-amex:0.89464	valid-logloss:0.21485	valid-amex:0.79555
# [1600]	train-logloss:0.15635	train-amex:0.90008	valid-logloss:0.21482	valid-amex:0.79588
# [1700]	train-logloss:0.15353	train-amex:0.90517	valid-logloss:0.21478	valid-amex:0.79581
# [1800]	train-logloss:0.15066	train-amex:0.91012	valid-logloss:0.21481	valid-amex:0.79624
# [1900]	train-logloss:0.14782	train-amex:0.91504	valid-logloss:0.21479	valid-amex:0.79591
# [2000]	train-logloss:0.14523	train-amex:0.91912	valid-logloss:0.21476	valid-amex:0.79572
# [2100]	train-logloss:0.14264	train-amex:0.92331	valid-logloss:0.21478	valid-amex:0.79561
# [2200]	train-logloss:0.14005	train-amex:0.92764	valid-logloss:0.21475	valid-amex:0.79609
# [2254]	train-logloss:0.13868	train-amex:0.93009	valid-logloss:0.21474	valid-amex:0.79572
# Our fold 4 CV score is 0.795553277012822
# Our out of folds CV score is 0.794857198067441
