# %% [markdown]
# # exp45
#
# lag_diffのXGB
#
#
# https://www.kaggle.com/code/ragnar123/amex-lgbm-dart-cv-0-7977

# %%
# ====================================================
# Library
# ====================================================
import gc
import warnings
warnings.filterwarnings('ignore')
import scipy as sp
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
from tqdm.auto import tqdm
import itertools

import lightgbm as lgb
import xgboost as xgb



from pytorch_tabnet.pretraining import TabNetPretrainer

from pytorch_tabnet.tab_model import TabNetRegressor
from pytorch_tabnet.tab_model import TabNetClassifier

import torch
from pytorch_tabnet.metrics import Metric

# %%
# ====================================================
# Get the difference
# ====================================================
def get_difference(data, num_features):
    df1 = []
    customer_ids = []
    for customer_id, df in tqdm(data.groupby(['customer_ID'])):
        # Get the differences
        diff_df1 = df[num_features].diff(1).iloc[[-1]].values.astype(np.float32)
        # Append to lists
        df1.append(diff_df1)
        customer_ids.append(customer_id)
    # Concatenate
    df1 = np.concatenate(df1, axis = 0)
    # Transform to dataframe
    df1 = pd.DataFrame(df1, columns = [col + '_diff1' for col in df[num_features].columns])
    # Add customer id
    df1['customer_ID'] = customer_ids
    return df1

# ====================================================
# Read & preprocess data and save it to disk
# ====================================================
def read_preprocess_data():
    train = pd.read_parquet('/content/data/train.parquet')
    features = train.drop(['customer_ID', 'S_2'], axis = 1).columns.to_list()
    cat_features = [
        "B_30",
        "B_38",
        "D_114",
        "D_116",
        "D_117",
        "D_120",
        "D_126",
        "D_63",
        "D_64",
        "D_66",
        "D_68",
    ]
    num_features = [col for col in features if col not in cat_features]
    print('Starting training feature engineer...')
    train_num_agg = train.groupby("customer_ID")[num_features].agg(['mean', 'std', 'min', 'max', 'last'])
    train_num_agg.columns = ['_'.join(x) for x in train_num_agg.columns]
    train_num_agg.reset_index(inplace = True)
    train_cat_agg = train.groupby("customer_ID")[cat_features].agg(['count', 'last', 'nunique'])
    train_cat_agg.columns = ['_'.join(x) for x in train_cat_agg.columns]
    train_cat_agg.reset_index(inplace = True)
    train_labels = pd.read_csv('../input/amex-default-prediction/train_labels.csv')
    # Transform float64 columns to float32
    cols = list(train_num_agg.dtypes[train_num_agg.dtypes == 'float64'].index)
    for col in tqdm(cols):
        train_num_agg[col] = train_num_agg[col].astype(np.float32)
    # Transform int64 columns to int32
    cols = list(train_cat_agg.dtypes[train_cat_agg.dtypes == 'int64'].index)
    for col in tqdm(cols):
        train_cat_agg[col] = train_cat_agg[col].astype(np.int32)
    # Get the difference
    train_diff = get_difference(train, num_features)
    train = train_num_agg.merge(train_cat_agg, how = 'inner', on = 'customer_ID').merge(train_diff, how = 'inner', on = 'customer_ID').merge(train_labels, how = 'inner', on = 'customer_ID')
    del train_num_agg, train_cat_agg, train_diff
    gc.collect()
    test = pd.read_parquet('../input/amex-fe/test_fe.parquet')
    print('Starting test feature engineer...')
    test_num_agg = test.groupby("customer_ID")[num_features].agg(['mean', 'std', 'min', 'max', 'last'])
    test_num_agg.columns = ['_'.join(x) for x in test_num_agg.columns]
    test_num_agg.reset_index(inplace = True)
    test_cat_agg = test.groupby("customer_ID")[cat_features].agg(['count', 'last', 'nunique'])
    test_cat_agg.columns = ['_'.join(x) for x in test_cat_agg.columns]
    test_cat_agg.reset_index(inplace = True)
    # Transform float64 columns to float32
    cols = list(test_num_agg.dtypes[test_num_agg.dtypes == 'float64'].index)
    for col in tqdm(cols):
        test_num_agg[col] = test_num_agg[col].astype(np.float32)
    # Transform int64 columns to int32
    cols = list(test_cat_agg.dtypes[test_cat_agg.dtypes == 'int64'].index)
    for col in tqdm(cols):
        test_cat_agg[col] = test_cat_agg[col].astype(np.int32)
    # Get the difference
    test_diff = get_difference(test, num_features)
    test = test_num_agg.merge(test_cat_agg, how = 'inner', on = 'customer_ID').merge(test_diff, how = 'inner', on = 'customer_ID')
    del test_num_agg, test_cat_agg, test_diff
    gc.collect()
    # Save files to disk
    train.to_parquet('../input/amex-fe/train_fe.parquet')
    test.to_parquet('../input/amex-fe/test_fe.parquet')

# Read & Preprocess Data
read_preprocess_data()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11668\217815574.py in <module>
#      86
#      87 # Read & Preprocess Data
# ---> 88 read_preprocess_data()
#
# ~\AppData\Local\Temp\ipykernel_11668\217815574.py in read_preprocess_data()
#      23 # ====================================================
#      24 def read_preprocess_data():
# ---> 25     train = pd.read_parquet('/content/data/train.parquet')
#      26     features = train.drop(['customer_ID', 'S_2'], axis = 1).columns.to_list()
#      27     cat_features = [
#
# ~\anaconda3\envs\amex\lib\site-packages\pandas\io\parquet.py in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, **kwargs)
#     498         storage_options=storage_options,
#     499         use_nullable_dtypes=use_nullable_dtypes,
# --> 500         **kwargs,
#     501     )
#
# ~\anaconda3\envs\amex\lib\site-packages\pandas\io\parquet.py in read(self, path, columns, use_nullable_dtypes, storage_options, **kwargs)
#     234             kwargs.pop("filesystem", None),
#     235             storage_options=storage_options,
# --> 236             mode="rb",
#     237         )
#     238         try:
#
# ~\anaconda3\envs\amex\lib\site-packages\pandas\io\parquet.py in _get_path_or_handle(path, fs, storage_options, mode, is_dir)
#     100         # this branch is used for example when reading from non-fsspec URLs
#     101         handles = get_handle(
# --> 102             path_or_handle, mode, is_text=False, storage_options=storage_options
#     103         )
#     104         fs = None
#
# ~\anaconda3\envs\amex\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     709         else:
#     710             # Binary mode
# --> 711             handle = open(handle, ioargs.mode)
#     712         handles.append(handle)
#     713
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/data/train.parquet'

# %% [markdown]
# # Training & Inference

# %%
# ====================================================
# Library
# ====================================================
import os
import gc
import warnings
warnings.filterwarnings('ignore')
import random
import scipy as sp
import numpy as np
import pandas as pd
import joblib
import itertools
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
from tqdm.auto import tqdm
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.preprocessing import LabelEncoder
import lightgbm as lgb
from itertools import combinations

import pickle

# ====================================================
# Configurations
# ====================================================
class CFG:
    
    
    # input_dir = '../feature/exp35_lagdiff/'
    input_dir = '../feature/exp03_amex-fe/'
    output_dir = '../output/exp45_tab_lagdiff_c3/'
    seed = 42
    n_folds = 5
    target = 'target'
    boosting_type = 'dart'
    metric = 'binary_logloss'
    model = "tab"
    ver = "exp45"

# ====================================================
# Seed everything
# ====================================================
def seed_everything(seed):
    random.seed(seed)
    np.random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)

# ====================================================
# Read data
# ====================================================
# def read_data():
#     train = pd.read_parquet(CFG.input_dir + 'train_diff.parquet')
#     test = pd.read_parquet(CFG.input_dir + 'test_diff.parquet')
#     return train, test

def read_data():
    train = pd.read_parquet(CFG.input_dir + 'train_fe_plus_plus.parquet')
    test = pd.read_parquet(CFG.input_dir + 'test_fe_plus_plus.parquet')
    return train, test

# ====================================================
# Amex metric
# ====================================================
def amex_metric(y_true, y_pred):
    labels = np.transpose(np.array([y_true, y_pred]))
    labels = labels[labels[:, 1].argsort()[::-1]]
    weights = np.where(labels[:,0]==0, 20, 1)
    cut_vals = labels[np.cumsum(weights) <= int(0.04 * np.sum(weights))]
    top_four = np.sum(cut_vals[:,0]) / np.sum(labels[:,0])
    gini = [0,0]
    for i in [1,0]:
        labels = np.transpose(np.array([y_true, y_pred]))
        labels = labels[labels[:, i].argsort()[::-1]]
        weight = np.where(labels[:,0]==0, 20, 1)
        weight_random = np.cumsum(weight / np.sum(weight))
        total_pos = np.sum(labels[:, 0] *  weight)
        cum_pos_found = np.cumsum(labels[:, 0] * weight)
        lorentz = cum_pos_found / total_pos
        gini[i] = np.sum((lorentz - weight_random) * weight)
    return 0.5 * (gini[1]/gini[0] + top_four)

# ====================================================
# LGBM amex metric
# ====================================================
def lgb_amex_metric(y_pred, y_true):
    y_true = y_true.get_label()
    return 'amex_metric', amex_metric(y_true, y_pred), True

# %%
seed_everything(CFG.seed)

train = pd.read_parquet('../feature/exp38_lagdiff_c3/train_lagdiff_c3.parquet')
test = pd.read_parquet('../feature/exp38_lagdiff_c3/test_lagdiff_c3.parquet')


print(train.shape)
print(test.shape)


train.fillna(value=0, inplace=True)
test.fillna(value=0, inplace=True)

# ver1 CV : 0.7810849444263961
# train = train.replace([np.inf, -np.inf],1000000000)
# test = test.replace([np.inf, -np.inf],1000000000)

# ver2 CV : 0.7809413511784129
# train = train.replace([np.inf, -np.inf],0)
# test = test.replace([np.inf, -np.inf],0)

# ver3 CV : 0.7808671773146323
# train = train.replace([np.inf, -np.inf],1000000)
# test = test.replace([np.inf, -np.inf],1000000)

# ver4 CV : 0.781115758105863
train = train.replace([np.inf, -np.inf],100000000000)
test = test.replace([np.inf, -np.inf],100000000000)
# Out:
# (458913, 2013)
# (924621, 2012)

# %%
def amex_metric_numpy(y_true: np.array, y_pred: np.array) -> float:

    # count of positives and negatives
    n_pos = y_true.sum()
    n_neg = y_true.shape[0] - n_pos

    # sorting by descring prediction values
    indices = np.argsort(y_pred)[::-1]
    preds, target = y_pred[indices], y_true[indices]

    # filter the top 4% by cumulative row weights
    weight = 20.0 - target * 19.0
    cum_norm_weight = (weight / weight.sum()).cumsum()
    four_pct_filter = cum_norm_weight <= 0.04

    # default rate captured at 4%
    d = target[four_pct_filter].sum() / n_pos

    # weighted gini coefficient
    lorentz = (target / n_pos).cumsum()
    gini = ((lorentz - cum_norm_weight) * weight).sum()

    # max weighted gini coefficient
    gini_max = 10 * n_neg * (1 - 19 / (n_pos + 20 * n_neg))

    # normalized weighted gini coefficient
    g = gini / gini_max

    return 0.5 * (g + d)

# %%
# using amex metric to evaluate tabnet
class Amex_tabnet(Metric):
    
    def __init__(self):
        self._name = 'amex_tabnet'
        self._maximize = True

    def __call__(self, y_true, y_pred):
        amex = amex_metric_numpy(y_true, y_pred[:, 1])
        return max(amex, 0.)


def amex_metric_np(preds: np.ndarray, target: np.ndarray) -> float:
    indices = np.argsort(preds)[::-1]
    preds, target = preds[indices], target[indices]

    weight = 20.0 - target * 19.0
    cum_norm_weight = (weight / weight.sum()).cumsum()
    four_pct_mask = cum_norm_weight <= 0.04
    d = np.sum(target[four_pct_mask]) / np.sum(target)

    weighted_target = target * weight
    lorentz = (weighted_target / weighted_target.sum()).cumsum()
    gini = ((lorentz - cum_norm_weight) * weight).sum()

    n_pos = np.sum(target)
    n_neg = target.shape[0] - n_pos
    gini_max = 10 * n_neg * (n_pos + 20 * n_neg - 19) / (n_pos + 20 * n_neg)

    g = gini / gini_max
    return 0.5 * (g + d)

# %%
cat_features = [
    "B_30",
    "B_38",
    "D_114",
    "D_116",
    "D_117",
    "D_120",
    "D_126",
    "D_63",
    "D_64",
    "D_66",
    "D_68"
]

# kmeans_list = ["kmeans pred 2","kmeans pred 3","kmeans pred 4"]

cat_features = [f"{cf}_last" for cf in cat_features]
# cat_features.extend(kmeans_list)

for cat_col in cat_features:
#     print(cat_col)
    encoder = LabelEncoder()
    train[cat_col] = encoder.fit_transform(train[cat_col])
    test[cat_col] = encoder.transform(test[cat_col])


features = [col for col in train.columns if col not in ['customer_ID', CFG.target]]
params = {
    'objective': 'binary',
    'metric': CFG.metric,
    'boosting': CFG.boosting_type,
    'seed': CFG.seed,
    'num_leaves': 100,
    'learning_rate': 0.01,
    'feature_fraction': 0.20,
    'bagging_freq': 10,
    'bagging_fraction': 0.50,
    'n_jobs': -1,
    'lambda_l2': 2,
    'min_data_in_leaf': 40,
    }
# Create a numpy array to store test predictions
test_predictions = np.zeros(len(test))
# Create a numpy array to store out of folds predictions
oof_predictions = np.zeros(len(train))

cids = []
tr_target = []


kfold = StratifiedKFold(n_splits = CFG.n_folds, shuffle = True, random_state = CFG.seed)
for fold, (trn_ind, val_ind) in enumerate(kfold.split(train, train[CFG.target])):
    print(' ')
    print('-'*50)
    print(f'Training fold {fold} with {len(features)} features...')
    x_train, x_val = train[features].iloc[trn_ind], train[features].iloc[val_ind]
    y_train, y_val = train[CFG.target].iloc[trn_ind], train[CFG.target].iloc[val_ind]

    
    
    model = TabNetClassifier(n_d = 32,
                         n_a = 32,
                         n_steps = 3,
                         gamma = 1.3,
                         n_independent = 2,
                         n_shared = 2,
                         momentum = 0.02,
                         clip_value = None,
                         lambda_sparse = 1e-3,
                         optimizer_fn = torch.optim.Adam,
                         optimizer_params = dict(lr = 1e-3, weight_decay=1e-3),
                         scheduler_fn = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts,
                         scheduler_params = {'T_0':5,
                                             'eta_min':1e-4,
                                             'T_mult':1,
                                             'last_epoch':-1},
                         mask_type = 'entmax',
                         seed = CFG.seed)
    
    print(f'start Training fold {fold}')
    model.fit(np.array(x_train),
                    np.array(y_train.values.ravel()),
                    eval_set = [(np.array(x_val), np.array(y_val.values.ravel()))],
                    max_epochs = 50,#50
                    patience = 5,#50
                    batch_size = 512,
                    eval_metric = ['auc', 'accuracy', Amex_tabnet]) # Last metric is used for early stoppin
    
    
    print(f'save model fold {fold}')
    file_path = f"{CFG.output_dir}{CFG.model}_fold{fold}"
    saved_filepath = model.save_model(file_path)
    
    
    # Save best model
    # joblib.dump(model, f'{CFG.output_dir}lgbm_{CFG.boosting_type}_fold{fold}_seed{CFG.seed}.pkl')
    # Predict validation
    
    # Add to out of folds array
    val_pred = model.predict_proba(np.array(x_val[features]))[:, 1]
    oof_predictions[val_ind] = val_pred
    
    cids.extend(train["customer_ID"].loc[val_ind])
    tr_target.extend(train["target"].loc[val_ind])
    
    # Predict the test set
    test_pred = model.predict_proba(np.array(test[features]))[:, 1]
    test_predictions += test_pred / CFG.n_folds
    
    # Compute fold metric
    score = amex_metric(y_val, val_pred)
    print(f'Our fold {fold} CV score is {score}')
    del x_train, x_val, y_train, y_val
    gc.collect()
    
# Compute out of folds metric
score = amex_metric(train[CFG.target], oof_predictions)
print(f'Our out of folds CV score is {score}')


# Create a dataframe to store test prediction
test_df = pd.DataFrame({'customer_ID': test['customer_ID'], 'prediction': test_predictions})
# test_df.to_csv(f'{CFG.output_dir}test_{CFG.model}_{score}_baseline_{CFG.n_folds}fold_seed{CFG.seed}.csv', index = False)
test_df.to_csv(f'{CFG.output_dir}test_{CFG.ver}_{CFG.model}_{score}_{CFG.n_folds}fold_seed{CFG.seed}.csv', index = False)


dic_oof = {
    "customer_ID":cids,
    "target":tr_target,
    "tabnet_oot":oof_predictions
}

# Create a dataframe to store out of folds predictions
oof_df = pd.DataFrame(dic_oof)
# oof_df = pd.DataFrame({'customer_ID': train['customer_ID'], 'target': train[CFG.target], 'prediction': oof_predictions})
oof_df.to_csv(f'{CFG.output_dir}oof_{CFG.ver}_{CFG.model}_{score}_{CFG.n_folds}fold_seed{CFG.seed}.csv', index = False)


# # Create a dataframe to store out of folds predictions
# oof_df = pd.DataFrame({'customer_ID': train['customer_ID'], 'target': train[CFG.target], 'prediction': oof_predictions})
# oof_df.to_csv(f'../output/Amex LGBM Dart CV 0.7977/oof_lgbm_{CFG.boosting_type}_baseline_{CFG.n_folds}fold_seed{CFG.seed}.csv', index = False)


# # Create a dataframe to store test prediction
# test_df = pd.DataFrame({'customer_ID': test['customer_ID'], 'prediction': test_predictions})
# test_df.to_csv(f'../output/Amex LGBM Dart CV 0.7977/test_lgbm_{CFG.boosting_type}_baseline_{CFG.n_folds}fold_seed{CFG.seed}.csv', index = False)
# Out:
#
# --------------------------------------------------
# Training fold 0 with 2011 features...
# start Training fold 0
# epoch 0  | loss: 0.55762 | val_0_auc: 0.91662 | val_0_accuracy: 0.84497 | val_0_amex_tabnet: 0.62433 |  0:06:42s
# epoch 1  | loss: 0.37143 | val_0_auc: 0.92839 | val_0_accuracy: 0.86275 | val_0_amex_tabnet: 0.66474 |  0:13:17s
# epoch 2  | loss: 0.33744 | val_0_auc: 0.93474 | val_0_accuracy: 0.86949 | val_0_amex_tabnet: 0.686   |  0:19:57s
# epoch 3  | loss: 0.32002 | val_0_auc: 0.9384  | val_0_accuracy: 0.87356 | val_0_amex_tabnet: 0.69716 |  0:26:37s
# epoch 4  | loss: 0.30752 | val_0_auc: 0.93973 | val_0_accuracy: 0.87426 | val_0_amex_tabnet: 0.70027 |  0:33:15s
# epoch 5  | loss: 0.28959 | val_0_auc: 0.94496 | val_0_accuracy: 0.88288 | val_0_amex_tabnet: 0.72781 |  0:39:58s
# epoch 6  | loss: 0.26798 | val_0_auc: 0.94862 | val_0_accuracy: 0.88701 | val_0_amex_tabnet: 0.74406 |  0:46:31s
# epoch 7  | loss: 0.25686 | val_0_auc: 0.95195 | val_0_accuracy: 0.89057 | val_0_amex_tabnet: 0.75709 |  0:52:54s
# epoch 8  | loss: 0.25053 | val_0_auc: 0.95312 | val_0_accuracy: 0.892   | val_0_amex_tabnet: 0.76162 |  0:59:07s
# epoch 9  | loss: 0.24811 | val_0_auc: 0.95353 | val_0_accuracy: 0.89227 | val_0_amex_tabnet: 0.76241 |  1:05:10s
# epoch 10 | loss: 0.24838 | val_0_auc: 0.95423 | val_0_accuracy: 0.89456 | val_0_amex_tabnet: 0.76808 |  1:11:04s
# epoch 11 | loss: 0.24282 | val_0_auc: 0.95717 | val_0_accuracy: 0.89878 | val_0_amex_tabnet: 0.77828 |  1:17:21s
# epoch 12 | loss: 0.23562 | val_0_auc: 0.9589  | val_0_accuracy: 0.90076 | val_0_amex_tabnet: 0.78258 |  1:23:53s
# epoch 13 | loss: 0.23174 | val_0_auc: 0.9595  | val_0_accuracy: 0.90158 | val_0_amex_tabnet: 0.78574 |  1:30:26s
# epoch 14 | loss: 0.22795 | val_0_auc: 0.96015 | val_0_accuracy: 0.90157 | val_0_amex_tabnet: 0.78734 |  1:36:57s
# epoch 15 | loss: 0.23317 | val_0_auc: 0.95909 | val_0_accuracy: 0.89919 | val_0_amex_tabnet: 0.78064 |  1:43:29s
# epoch 16 | loss: 0.23074 | val_0_auc: 0.95933 | val_0_accuracy: 0.90125 | val_0_amex_tabnet: 0.7854  |  1:49:59s
# epoch 17 | loss: 0.22896 | val_0_auc: 0.96002 | val_0_accuracy: 0.90108 | val_0_amex_tabnet: 0.78672 |  1:56:28s
# epoch 18 | loss: 0.22673 | val_0_auc: 0.96053 | val_0_accuracy: 0.90241 | val_0_amex_tabnet: 0.78843 |  2:02:55s
# epoch 19 | loss: 0.22458 | val_0_auc: 0.96095 | val_0_accuracy: 0.90255 | val_0_amex_tabnet: 0.79112 |  2:09:18s
# epoch 20 | loss: 0.22877 | val_0_auc: 0.96018 | val_0_accuracy: 0.90231 | val_0_amex_tabnet: 0.78828 |  2:15:45s
# epoch 21 | loss: 0.22788 | val_0_auc: 0.96056 | val_0_accuracy: 0.90239 | val_0_amex_tabnet: 0.79005 |  2:22:09s
# epoch 22 | loss: 0.22687 | val_0_auc: 0.96082 | val_0_accuracy: 0.90266 | val_0_amex_tabnet: 0.79064 |  2:28:31s
# epoch 23 | loss: 0.22472 | val_0_auc: 0.96078 | val_0_accuracy: 0.90313 | val_0_amex_tabnet: 0.79148 |  2:34:46s
# epoch 24 | loss: 0.22292 | val_0_auc: 0.96096 | val_0_accuracy: 0.90299 | val_0_amex_tabnet: 0.7905  |  2:40:51s
# epoch 25 | loss: 0.22749 | val_0_auc: 0.9603  | val_0_accuracy: 0.9016  | val_0_amex_tabnet: 0.78789 |  2:47:11s
# epoch 26 | loss: 0.2266  | val_0_auc: 0.96042 | val_0_accuracy: 0.90223 | val_0_amex_tabnet: 0.78984 |  2:53:24s
# epoch 27 | loss: 0.22564 | val_0_auc: 0.96068 | val_0_accuracy: 0.90269 | val_0_amex_tabnet: 0.78938 |  2:59:29s
# epoch 28 | loss: 0.22339 | val_0_auc: 0.96089 | val_0_accuracy: 0.90198 | val_0_amex_tabnet: 0.79117 |  3:05:19s
#
# Early stopping occurred at epoch 28 with best_epoch = 23 and best_val_0_amex_tabnet = 0.79148
# save model fold 0
# Successfully saved model at ../output/exp45_tab_lagdiff_c3/tab_fold0.zip
# Our fold 0 CV score is 0.7914815085691028
#
# --------------------------------------------------
# Training fold 1 with 2011 features...
# start Training fold 1
# epoch 0  | loss: 0.55786 | val_0_auc: 0.91411 | val_0_accuracy: 0.83684 | val_0_amex_tabnet: 0.60758 |  0:06:34s
# epoch 1  | loss: 0.37052 | val_0_auc: 0.92637 | val_0_accuracy: 0.85822 | val_0_amex_tabnet: 0.65211 |  0:13:07s
# epoch 2  | loss: 0.33319 | val_0_auc: 0.9312  | val_0_accuracy: 0.8591  | val_0_amex_tabnet: 0.6719  |  0:19:40s
# epoch 3  | loss: 0.30589 | val_0_auc: 0.93734 | val_0_accuracy: 0.87209 | val_0_amex_tabnet: 0.69828 |  0:26:12s
# epoch 4  | loss: 0.29101 | val_0_auc: 0.93857 | val_0_accuracy: 0.87265 | val_0_amex_tabnet: 0.70146 |  0:32:44s
# epoch 5  | loss: 0.27857 | val_0_auc: 0.94449 | val_0_accuracy: 0.88149 | val_0_amex_tabnet: 0.72462 |  0:39:17s
# epoch 6  | loss: 0.26151 | val_0_auc: 0.95071 | val_0_accuracy: 0.88958 | val_0_amex_tabnet: 0.75114 |  0:45:43s
# epoch 7  | loss: 0.25114 | val_0_auc: 0.95139 | val_0_accuracy: 0.8901  | val_0_amex_tabnet: 0.75405 |  0:51:59s
# epoch 8  | loss: 0.24737 | val_0_auc: 0.9531  | val_0_accuracy: 0.8924  | val_0_amex_tabnet: 0.7574  |  0:58:06s
# epoch 9  | loss: 0.24441 | val_0_auc: 0.9536  | val_0_accuracy: 0.89305 | val_0_amex_tabnet: 0.75917 |  1:04:06s
# epoch 10 | loss: 0.24634 | val_0_auc: 0.9537  | val_0_accuracy: 0.89405 | val_0_amex_tabnet: 0.76093 |  1:09:54s
# epoch 11 | loss: 0.24018 | val_0_auc: 0.9569  | val_0_accuracy: 0.8967  | val_0_amex_tabnet: 0.77256 |  1:15:29s
# epoch 12 | loss: 0.2343  | val_0_auc: 0.95808 | val_0_accuracy: 0.89935 | val_0_amex_tabnet: 0.77668 |  1:21:57s
# epoch 13 | loss: 0.23037 | val_0_auc: 0.95906 | val_0_accuracy: 0.90056 | val_0_amex_tabnet: 0.77979 |  1:28:28s
# epoch 14 | loss: 0.22665 | val_0_auc: 0.95973 | val_0_accuracy: 0.90132 | val_0_amex_tabnet: 0.78235 |  1:34:58s
# epoch 15 | loss: 0.23227 | val_0_auc: 0.95851 | val_0_accuracy: 0.89859 | val_0_amex_tabnet: 0.77965 |  1:41:30s
# epoch 16 | loss: 0.23021 | val_0_auc: 0.95842 | val_0_accuracy: 0.89912 | val_0_amex_tabnet: 0.77943 |  1:47:58s
# epoch 17 | loss: 0.229   | val_0_auc: 0.95939 | val_0_accuracy: 0.90061 | val_0_amex_tabnet: 0.78178 |  1:54:26s
# epoch 18 | loss: 0.22631 | val_0_auc: 0.9598  | val_0_accuracy: 0.9011  | val_0_amex_tabnet: 0.78335 |  2:00:53s
# epoch 19 | loss: 0.22402 | val_0_auc: 0.96012 | val_0_accuracy: 0.90216 | val_0_amex_tabnet: 0.78426 |  2:07:17s
# epoch 20 | loss: 0.22893 | val_0_auc: 0.95885 | val_0_accuracy: 0.89903 | val_0_amex_tabnet: 0.78148 |  2:13:46s
# epoch 21 | loss: 0.22843 | val_0_auc: 0.95929 | val_0_accuracy: 0.90055 | val_0_amex_tabnet: 0.78235 |  2:20:12s
# epoch 22 | loss: 0.22644 | val_0_auc: 0.95969 | val_0_accuracy: 0.9009  | val_0_amex_tabnet: 0.78433 |  2:26:34s
# epoch 23 | loss: 0.22439 | val_0_auc: 0.95995 | val_0_accuracy: 0.89935 | val_0_amex_tabnet: 0.78501 |  2:32:48s
# epoch 24 | loss: 0.22206 | val_0_auc: 0.96018 | val_0_accuracy: 0.90172 | val_0_amex_tabnet: 0.78625 |  2:38:49s
# epoch 25 | loss: 0.22737 | val_0_auc: 0.95982 | val_0_accuracy: 0.90183 | val_0_amex_tabnet: 0.78552 |  2:45:13s
# epoch 26 | loss: 0.22618 | val_0_auc: 0.95989 | val_0_accuracy: 0.90128 | val_0_amex_tabnet: 0.78468 |  2:51:31s
# epoch 27 | loss: 0.22486 | val_0_auc: 0.96    | val_0_accuracy: 0.90187 | val_0_amex_tabnet: 0.7845  |  2:57:36s
# epoch 28 | loss: 0.22288 | val_0_auc: 0.9602  | val_0_accuracy: 0.90096 | val_0_amex_tabnet: 0.78518 |  3:03:31s
# epoch 29 | loss: 0.22094 | val_0_auc: 0.96014 | val_0_accuracy: 0.90227 | val_0_amex_tabnet: 0.78464 |  3:09:05s
#
# Early stopping occurred at epoch 29 with best_epoch = 24 and best_val_0_amex_tabnet = 0.78625
# save model fold 1
# Successfully saved model at ../output/exp45_tab_lagdiff_c3/tab_fold1.zip
# Our fold 1 CV score is 0.7862507197680477
#
# --------------------------------------------------
# Training fold 2 with 2011 features...
# start Training fold 2
# epoch 0  | loss: 0.5603  | val_0_auc: 0.91384 | val_0_accuracy: 0.84531 | val_0_amex_tabnet: 0.61749 |  0:06:31s
# epoch 1  | loss: 0.3626  | val_0_auc: 0.92926 | val_0_accuracy: 0.86548 | val_0_amex_tabnet: 0.66728 |  0:13:01s
# epoch 2  | loss: 0.3117  | val_0_auc: 0.93902 | val_0_accuracy: 0.8758  | val_0_amex_tabnet: 0.70905 |  0:19:31s
# epoch 3  | loss: 0.28401 | val_0_auc: 0.94152 | val_0_accuracy: 0.87866 | val_0_amex_tabnet: 0.7175  |  0:26:01s
# epoch 4  | loss: 0.2765  | val_0_auc: 0.94251 | val_0_accuracy: 0.87981 | val_0_amex_tabnet: 0.7215  |  0:32:30s
# epoch 5  | loss: 0.27218 | val_0_auc: 0.94573 | val_0_accuracy: 0.88395 | val_0_amex_tabnet: 0.73343 |  0:39:01s
# epoch 6  | loss: 0.25961 | val_0_auc: 0.95085 | val_0_accuracy: 0.88979 | val_0_amex_tabnet: 0.74903 |  0:45:25s
# epoch 7  | loss: 0.25075 | val_0_auc: 0.95228 | val_0_accuracy: 0.89271 | val_0_amex_tabnet: 0.757   |  0:51:38s
# epoch 8  | loss: 0.24645 | val_0_auc: 0.9528  | val_0_accuracy: 0.89209 | val_0_amex_tabnet: 0.75761 |  0:57:42s
# epoch 9  | loss: 0.2444  | val_0_auc: 0.95322 | val_0_accuracy: 0.89275 | val_0_amex_tabnet: 0.75969 |  1:03:39s
# epoch 10 | loss: 0.24558 | val_0_auc: 0.9539  | val_0_accuracy: 0.89424 | val_0_amex_tabnet: 0.76325 |  1:09:24s
# epoch 11 | loss: 0.24082 | val_0_auc: 0.95666 | val_0_accuracy: 0.89733 | val_0_amex_tabnet: 0.77604 |  1:15:00s
# epoch 12 | loss: 0.23533 | val_0_auc: 0.95756 | val_0_accuracy: 0.89754 | val_0_amex_tabnet: 0.77841 |  1:20:30s
# epoch 13 | loss: 0.23186 | val_0_auc: 0.95846 | val_0_accuracy: 0.89949 | val_0_amex_tabnet: 0.78188 |  1:25:58s
# epoch 14 | loss: 0.22764 | val_0_auc: 0.95901 | val_0_accuracy: 0.90019 | val_0_amex_tabnet: 0.78416 |  1:31:29s
# epoch 15 | loss: 0.23286 | val_0_auc: 0.95852 | val_0_accuracy: 0.89949 | val_0_amex_tabnet: 0.78205 |  1:36:56s
# epoch 16 | loss: 0.23092 | val_0_auc: 0.9575  | val_0_accuracy: 0.89919 | val_0_amex_tabnet: 0.77792 |  1:42:25s
# epoch 17 | loss: 0.22869 | val_0_auc: 0.95923 | val_0_accuracy: 0.90062 | val_0_amex_tabnet: 0.78537 |  1:48:47s
# epoch 18 | loss: 0.22608 | val_0_auc: 0.95982 | val_0_accuracy: 0.90091 | val_0_amex_tabnet: 0.78556 |  1:55:15s
# epoch 19 | loss: 0.22321 | val_0_auc: 0.9601  | val_0_accuracy: 0.90103 | val_0_amex_tabnet: 0.78792 |  2:01:49s
# epoch 20 | loss: 0.22876 | val_0_auc: 0.95947 | val_0_accuracy: 0.90104 | val_0_amex_tabnet: 0.78447 |  2:08:30s
# epoch 21 | loss: 0.22749 | val_0_auc: 0.95973 | val_0_accuracy: 0.90143 | val_0_amex_tabnet: 0.78757 |  2:15:06s
# epoch 22 | loss: 0.22583 | val_0_auc: 0.95986 | val_0_accuracy: 0.9016  | val_0_amex_tabnet: 0.78804 |  2:21:34s
# epoch 23 | loss: 0.22399 | val_0_auc: 0.95999 | val_0_accuracy: 0.90194 | val_0_amex_tabnet: 0.78586 |  2:27:47s
# epoch 24 | loss: 0.22155 | val_0_auc: 0.96033 | val_0_accuracy: 0.9023  | val_0_amex_tabnet: 0.78742 |  2:33:45s
# epoch 25 | loss: 0.22674 | val_0_auc: 0.9596  | val_0_accuracy: 0.90099 | val_0_amex_tabnet: 0.78536 |  2:40:06s
# epoch 26 | loss: 0.22584 | val_0_auc: 0.95989 | val_0_accuracy: 0.90139 | val_0_amex_tabnet: 0.78618 |  2:46:28s
# epoch 27 | loss: 0.22442 | val_0_auc: 0.95992 | val_0_accuracy: 0.90181 | val_0_amex_tabnet: 0.7852  |  2:52:39s
#
# Early stopping occurred at epoch 27 with best_epoch = 22 and best_val_0_amex_tabnet = 0.78804
# save model fold 2
# Successfully saved model at ../output/exp45_tab_lagdiff_c3/tab_fold2.zip
# Our fold 2 CV score is 0.7880353131198985
#
# --------------------------------------------------
# Training fold 3 with 2011 features...
# start Training fold 3
# epoch 0  | loss: 0.5569  | val_0_auc: 0.91479 | val_0_accuracy: 0.8472  | val_0_amex_tabnet: 0.6198  |  0:06:34s
# epoch 1  | loss: 0.36851 | val_0_auc: 0.92596 | val_0_accuracy: 0.86136 | val_0_amex_tabnet: 0.65478 |  0:13:07s
# epoch 2  | loss: 0.33217 | val_0_auc: 0.93091 | val_0_accuracy: 0.86717 | val_0_amex_tabnet: 0.6721  |  0:19:41s
# epoch 3  | loss: 0.31288 | val_0_auc: 0.93341 | val_0_accuracy: 0.86854 | val_0_amex_tabnet: 0.67871 |  0:26:15s
# epoch 4  | loss: 0.30237 | val_0_auc: 0.93444 | val_0_accuracy: 0.86978 | val_0_amex_tabnet: 0.68351 |  0:32:50s
# epoch 5  | loss: 0.2888  | val_0_auc: 0.94248 | val_0_accuracy: 0.8818  | val_0_amex_tabnet: 0.71986 |  0:39:22s
# epoch 6  | loss: 0.26656 | val_0_auc: 0.94886 | val_0_accuracy: 0.88856 | val_0_amex_tabnet: 0.74383 |  0:45:49s
# epoch 7  | loss: 0.25377 | val_0_auc: 0.95121 | val_0_accuracy: 0.89137 | val_0_amex_tabnet: 0.74957 |  0:52:07s
# epoch 8  | loss: 0.24876 | val_0_auc: 0.95185 | val_0_accuracy: 0.89163 | val_0_amex_tabnet: 0.75166 |  0:58:15s
# epoch 9  | loss: 0.24649 | val_0_auc: 0.95238 | val_0_accuracy: 0.89234 | val_0_amex_tabnet: 0.75514 |  1:04:18s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11668\1023821522.py in <module>
#      85                     patience = 5,#50
#      86                     batch_size = 512,
# ---> 87                     eval_metric = ['auc', 'accuracy', Amex_tabnet]) # Last metric is used for early stoppin
#      88
#      89
#
# ~\anaconda3\envs\amex\lib\site-packages\pytorch_tabnet\abstract_model.py in fit(self, X_train, y_train, eval_set, eval_name, eval_metric, loss_fn, weights, max_epochs, patience, batch_size, virtual_batch_size, num_workers, drop_last, callbacks, pin_memory, from_unsupervised, warm_start, augmentations)
#     239             self._callback_container.on_epoch_begin(epoch_idx)
#     240
# --> 241             self._train_epoch(train_dataloader)
#     242
#     243             # Apply predict epoch to all eval sets
#
# ~\anaconda3\envs\amex\lib\site-packages\pytorch_tabnet\abstract_model.py in _train_epoch(self, train_loader)
#     455             self._callback_container.on_batch_begin(batch_idx)
#     456
# --> 457             batch_logs = self._train_batch(X, y)
#     458
#     459             self._callback_container.on_batch_end(batch_idx, batch_logs)
#
# ~\anaconda3\envs\amex\lib\site-packages\pytorch_tabnet\abstract_model.py in _train_batch(self, X, y)
#     493             param.grad = None
#     494
# --> 495         output, M_loss = self.network(X)
#     496
#     497         loss = self.compute_loss(output, y)
#
# ~\anaconda3\envs\amex\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\anaconda3\envs\amex\lib\site-packages\pytorch_tabnet\tab_network.py in forward(self, x)
#     584     def forward(self, x):
#     585         x = self.embedder(x)
# --> 586         return self.tabnet(x)
#     587
#     588     def forward_masks(self, x):
#
# ~\anaconda3\envs\amex\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\anaconda3\envs\amex\lib\site-packages\pytorch_tabnet\tab_network.py in forward(self, x)
#     469     def forward(self, x):
#     470         res = 0
# --> 471         steps_output, M_loss = self.encoder(x)
#     472         res = torch.sum(torch.stack(steps_output, dim=0), dim=0)
#     473
#
# ~\anaconda3\envs\amex\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\anaconda3\envs\amex\lib\site-packages\pytorch_tabnet\tab_network.py in forward(self, x, prior)
#     158         steps_output = []
#     159         for step in range(self.n_steps):
# --> 160             M = self.att_transformers[step](prior, att)
#     161             M_loss += torch.mean(
#     162                 torch.sum(torch.mul(M, torch.log(M + self.epsilon)), dim=1)
#
# ~\anaconda3\envs\amex\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\anaconda3\envs\amex\lib\site-packages\pytorch_tabnet\tab_network.py in forward(self, priors, processed_feat)
#     638         x = self.bn(x)
#     639         x = torch.mul(x, priors)
# --> 640         x = self.selector(x)
#     641         return x
#     642
#
# ~\anaconda3\envs\amex\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\anaconda3\envs\amex\lib\site-packages\pytorch_tabnet\sparsemax.py in forward(self, input)
#     202
#     203     def forward(self, input):
# --> 204         return entmax15(input, self.dim)
#     205
#     206
#
# ~\anaconda3\envs\amex\lib\site-packages\pytorch_tabnet\sparsemax.py in forward(ctx, input, dim)
#     125         input = input / 2  # divide by 2 to solve actual Entmax
#     126
# --> 127         tau_star, _ = Entmax15Function._threshold_and_support(input, dim)
#     128         output = torch.clamp(input - tau_star, min=0) ** 2
#     129         ctx.save_for_backward(output)
#
# ~\anaconda3\envs\amex\lib\site-packages\pytorch_tabnet\sparsemax.py in _threshold_and_support(input, dim)
#     142     @staticmethod
#     143     def _threshold_and_support(input, dim=-1):
# --> 144         Xsrt, _ = torch.sort(input, descending=True, dim=dim)
#     145
#     146         rho = _make_ix_like(input, dim)
#
# KeyboardInterrupt:
