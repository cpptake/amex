# %% [markdown]
# # exp43
#
# lag_diffのXGB
#
#
# https://www.kaggle.com/code/ragnar123/amex-lgbm-dart-cv-0-7977

# %%
# ====================================================
# Library
# ====================================================
import gc
import warnings
warnings.filterwarnings('ignore')
import scipy as sp
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
from tqdm.auto import tqdm
import itertools

import lightgbm as lgb
import xgboost as xgb

# %%
print(xgb.__version__)
# Out:
# 1.5.0

# %%
# ====================================================
# Get the difference
# ====================================================
def get_difference(data, num_features):
    df1 = []
    customer_ids = []
    for customer_id, df in tqdm(data.groupby(['customer_ID'])):
        # Get the differences
        diff_df1 = df[num_features].diff(1).iloc[[-1]].values.astype(np.float32)
        # Append to lists
        df1.append(diff_df1)
        customer_ids.append(customer_id)
    # Concatenate
    df1 = np.concatenate(df1, axis = 0)
    # Transform to dataframe
    df1 = pd.DataFrame(df1, columns = [col + '_diff1' for col in df[num_features].columns])
    # Add customer id
    df1['customer_ID'] = customer_ids
    return df1

# ====================================================
# Read & preprocess data and save it to disk
# ====================================================
def read_preprocess_data():
    train = pd.read_parquet('/content/data/train.parquet')
    features = train.drop(['customer_ID', 'S_2'], axis = 1).columns.to_list()
    cat_features = [
        "B_30",
        "B_38",
        "D_114",
        "D_116",
        "D_117",
        "D_120",
        "D_126",
        "D_63",
        "D_64",
        "D_66",
        "D_68",
    ]
    num_features = [col for col in features if col not in cat_features]
    print('Starting training feature engineer...')
    train_num_agg = train.groupby("customer_ID")[num_features].agg(['mean', 'std', 'min', 'max', 'last'])
    train_num_agg.columns = ['_'.join(x) for x in train_num_agg.columns]
    train_num_agg.reset_index(inplace = True)
    train_cat_agg = train.groupby("customer_ID")[cat_features].agg(['count', 'last', 'nunique'])
    train_cat_agg.columns = ['_'.join(x) for x in train_cat_agg.columns]
    train_cat_agg.reset_index(inplace = True)
    train_labels = pd.read_csv('../input/amex-default-prediction/train_labels.csv')
    # Transform float64 columns to float32
    cols = list(train_num_agg.dtypes[train_num_agg.dtypes == 'float64'].index)
    for col in tqdm(cols):
        train_num_agg[col] = train_num_agg[col].astype(np.float32)
    # Transform int64 columns to int32
    cols = list(train_cat_agg.dtypes[train_cat_agg.dtypes == 'int64'].index)
    for col in tqdm(cols):
        train_cat_agg[col] = train_cat_agg[col].astype(np.int32)
    # Get the difference
    train_diff = get_difference(train, num_features)
    train = train_num_agg.merge(train_cat_agg, how = 'inner', on = 'customer_ID').merge(train_diff, how = 'inner', on = 'customer_ID').merge(train_labels, how = 'inner', on = 'customer_ID')
    del train_num_agg, train_cat_agg, train_diff
    gc.collect()
    test = pd.read_parquet('../input/amex-fe/test_fe.parquet')
    print('Starting test feature engineer...')
    test_num_agg = test.groupby("customer_ID")[num_features].agg(['mean', 'std', 'min', 'max', 'last'])
    test_num_agg.columns = ['_'.join(x) for x in test_num_agg.columns]
    test_num_agg.reset_index(inplace = True)
    test_cat_agg = test.groupby("customer_ID")[cat_features].agg(['count', 'last', 'nunique'])
    test_cat_agg.columns = ['_'.join(x) for x in test_cat_agg.columns]
    test_cat_agg.reset_index(inplace = True)
    # Transform float64 columns to float32
    cols = list(test_num_agg.dtypes[test_num_agg.dtypes == 'float64'].index)
    for col in tqdm(cols):
        test_num_agg[col] = test_num_agg[col].astype(np.float32)
    # Transform int64 columns to int32
    cols = list(test_cat_agg.dtypes[test_cat_agg.dtypes == 'int64'].index)
    for col in tqdm(cols):
        test_cat_agg[col] = test_cat_agg[col].astype(np.int32)
    # Get the difference
    test_diff = get_difference(test, num_features)
    test = test_num_agg.merge(test_cat_agg, how = 'inner', on = 'customer_ID').merge(test_diff, how = 'inner', on = 'customer_ID')
    del test_num_agg, test_cat_agg, test_diff
    gc.collect()
    # Save files to disk
    train.to_parquet('../input/amex-fe/train_fe.parquet')
    test.to_parquet('../input/amex-fe/test_fe.parquet')

# Read & Preprocess Data
read_preprocess_data()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24236\217815574.py in <module>
#      86
#      87 # Read & Preprocess Data
# ---> 88 read_preprocess_data()
#
# ~\AppData\Local\Temp\ipykernel_24236\217815574.py in read_preprocess_data()
#      23 # ====================================================
#      24 def read_preprocess_data():
# ---> 25     train = pd.read_parquet('/content/data/train.parquet')
#      26     features = train.drop(['customer_ID', 'S_2'], axis = 1).columns.to_list()
#      27     cat_features = [
#
# ~\anaconda3\envs\amex\lib\site-packages\pandas\io\parquet.py in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, **kwargs)
#     498         storage_options=storage_options,
#     499         use_nullable_dtypes=use_nullable_dtypes,
# --> 500         **kwargs,
#     501     )
#
# ~\anaconda3\envs\amex\lib\site-packages\pandas\io\parquet.py in read(self, path, columns, use_nullable_dtypes, storage_options, **kwargs)
#     234             kwargs.pop("filesystem", None),
#     235             storage_options=storage_options,
# --> 236             mode="rb",
#     237         )
#     238         try:
#
# ~\anaconda3\envs\amex\lib\site-packages\pandas\io\parquet.py in _get_path_or_handle(path, fs, storage_options, mode, is_dir)
#     100         # this branch is used for example when reading from non-fsspec URLs
#     101         handles = get_handle(
# --> 102             path_or_handle, mode, is_text=False, storage_options=storage_options
#     103         )
#     104         fs = None
#
# ~\anaconda3\envs\amex\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     709         else:
#     710             # Binary mode
# --> 711             handle = open(handle, ioargs.mode)
#     712         handles.append(handle)
#     713
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/data/train.parquet'

# %% [markdown]
# # Training & Inference

# %%
# ====================================================
# Library
# ====================================================
import os
import gc
import warnings
warnings.filterwarnings('ignore')
import random
import scipy as sp
import numpy as np
import pandas as pd
import joblib
import itertools
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
from tqdm.auto import tqdm
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.preprocessing import LabelEncoder
import lightgbm as lgb
from itertools import combinations

import pickle

# ====================================================
# Configurations
# ====================================================
class CFG:
    
    
    # input_dir = '../feature/exp35_lagdiff/'
    input_dir = '../feature/exp03_amex-fe/'
    output_dir = '../output/exp43_xgb_611/'
    seed = 611
    n_folds = 5
    target = 'target'
    boosting_type = 'dart'
    metric = 'binary_logloss'
    model = "xgb"
    ver ="exp43"

# ====================================================
# Seed everything
# ====================================================
def seed_everything(seed):
    random.seed(seed)
    np.random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)

# ====================================================
# Read data
# ====================================================
# def read_data():
#     train = pd.read_parquet(CFG.input_dir + 'train_diff.parquet')
#     test = pd.read_parquet(CFG.input_dir + 'test_diff.parquet')
#     return train, test

def read_data():
    train = pd.read_parquet(CFG.input_dir + 'train_fe_plus_plus.parquet')
    test = pd.read_parquet(CFG.input_dir + 'test_fe_plus_plus.parquet')
    return train, test

# ====================================================
# Amex metric
# ====================================================
def amex_metric(y_true, y_pred):
    labels = np.transpose(np.array([y_true, y_pred]))
    labels = labels[labels[:, 1].argsort()[::-1]]
    weights = np.where(labels[:,0]==0, 20, 1)
    cut_vals = labels[np.cumsum(weights) <= int(0.04 * np.sum(weights))]
    top_four = np.sum(cut_vals[:,0]) / np.sum(labels[:,0])
    gini = [0,0]
    for i in [1,0]:
        labels = np.transpose(np.array([y_true, y_pred]))
        labels = labels[labels[:, i].argsort()[::-1]]
        weight = np.where(labels[:,0]==0, 20, 1)
        weight_random = np.cumsum(weight / np.sum(weight))
        total_pos = np.sum(labels[:, 0] *  weight)
        cum_pos_found = np.cumsum(labels[:, 0] * weight)
        lorentz = cum_pos_found / total_pos
        gini[i] = np.sum((lorentz - weight_random) * weight)
    return 0.5 * (gini[1]/gini[0] + top_four)

# ====================================================
# LGBM amex metric
# ====================================================
def lgb_amex_metric(y_pred, y_true):
    y_true = y_true.get_label()
    return 'amex_metric', amex_metric(y_true, y_pred), True

# %%
seed_everything(CFG.seed)


train = pd.read_parquet('../feature/exp38_lagdiff_c3/train_lagdiff_c3.parquet')
test = pd.read_parquet('../feature/exp38_lagdiff_c3/test_lagdiff_c3.parquet')


# OneDrive/デスクトップ/code/AMEX/feature/exp38_lagdiff_c3/test_lagdiff_c3.parquet

# train = pd.read_parquet('../feature/exp35_lagdiff/train_lagdiff.parquet')
# test = pd.read_parquet('../feature/exp35_lagdiff/test_lagdiff.parquet')

# train, test = read_data()

# train_c3 = pd.read_pickle('../feature/exp18_4_tsfresh/train_c3.pkl')
# test_c3 = pd.read_pickle('../feature/exp18_4_tsfresh/test_c3.pkl')

# train = train.merge(train_c3,on = "customer_ID",how = "left")
# test = test.merge(test_c3,on = "customer_ID",how = "left")

# del train_c3,test_c3
# gc.collect

# print(train.shape)
# print(test.shape)

# %%
def xgb_amex(y_pred, y_true):
    return 'amex', amex_metric_np(y_pred,y_true.get_label())


def amex_metric_np(preds: np.ndarray, target: np.ndarray) -> float:
    indices = np.argsort(preds)[::-1]
    preds, target = preds[indices], target[indices]

    weight = 20.0 - target * 19.0
    cum_norm_weight = (weight / weight.sum()).cumsum()
    four_pct_mask = cum_norm_weight <= 0.04
    d = np.sum(target[four_pct_mask]) / np.sum(target)

    weighted_target = target * weight
    lorentz = (weighted_target / weighted_target.sum()).cumsum()
    gini = ((lorentz - cum_norm_weight) * weight).sum()

    n_pos = np.sum(target)
    n_neg = target.shape[0] - n_pos
    gini_max = 10 * n_neg * (n_pos + 20 * n_neg - 19) / (n_pos + 20 * n_neg)

    g = gini / gini_max
    return 0.5 * (g + d)

# %%
train.fillna(value=0, inplace=True)
test.fillna(value=0, inplace=True)

## infを含むデータを外れ値（－１００００）に置換
train = train.replace([np.inf, -np.inf],100000000000)
test = test.replace([np.inf, -np.inf],100000000000)

# %%
cat_features = [
    "B_30",
    "B_38",
    "D_114",
    "D_116",
    "D_117",
    "D_120",
    "D_126",
    "D_63",
    "D_64",
    "D_66",
    "D_68"
]

# kmeans_list = ["kmeans pred 2","kmeans pred 3","kmeans pred 4"]

cat_features = [f"{cf}_last" for cf in cat_features]
# cat_features.extend(kmeans_list)

# for cat_col in cat_features:
# #     print(cat_col)
#     encoder = LabelEncoder()
#     train[cat_col] = encoder.fit_transform(train[cat_col])
#     test[cat_col] = encoder.transform(test[cat_col])


features = [col for col in train.columns if col not in ['customer_ID', CFG.target]]

xgb_parameters={
        'max_depth': 9,#7 # optuna 9
        'eta': 0.03,
        'subsample': 0.88,
        'colsample_bytree': 0.5,
        'objective': 'binary:logistic',
        'learning_rate' : 0.008971755769136095,#0.026582608139330333
        'tree_method': 'hist',#gpu_hist
        # 'predictor': 'gpu_predictor',
        'random_state': 42,
        'gamma': 1.5,
        'min_child_weight': 19,#8 # optuna 19
        'lambda': 70,
    }

# Create a numpy array to store test predictions
test_predictions = np.zeros(len(test))
# Create a numpy array to store out of folds predictions
oof_predictions = np.zeros(len(train))

cids = []
tr_target = []

# epoch = [10000,7500,7500,8500,10500]

kfold = StratifiedKFold(n_splits = CFG.n_folds, shuffle = True, random_state = CFG.seed)
for fold, (trn_ind, val_ind) in enumerate(kfold.split(train, train[CFG.target])):
    print(' ')
    print('-'*50)
    print(f'Training fold {fold} with {len(features)} features...')
    x_train, x_val = train[features].iloc[trn_ind], train[features].iloc[val_ind]
    y_train, y_val = train[CFG.target].iloc[trn_ind], train[CFG.target].iloc[val_ind]
    
    dtrain = xgb.DMatrix(data=x_train, label=y_train)
    dvalid = xgb.DMatrix(data=x_val, label=y_val)
    dtest = xgb.DMatrix(data=test[features])
    
#     des = DartEarlyStopping("valid_1", CFG.metric, 1000)
  
    model = xgb.train(
            xgb_parameters,
            dtrain=dtrain,
            num_boost_round=9999,#9999
            evals=[(dtrain, "train"), (dvalid, "valid")],
            early_stopping_rounds=500,
            feval=xgb_amex,
            maximize=True,
            verbose_eval=100
        )
    
    
    # Save best model
    model.save_model(f'{CFG.output_dir}{CFG.model}_{CFG.ver}_{CFG.boosting_type}_fold{fold}_seed{CFG.seed}.xgb')
#     joblib.dump(model, f'{CFG.output_dir}lgbm_{CFG.boosting_type}_fold{fold}_seed{CFG.seed}.pkl')
    # Predict validation
    val_pred = model.predict(dvalid)
    # Add to out of folds array
    oof_predictions[val_ind] = val_pred
    
    cids.extend(train["customer_ID"].loc[val_ind])
    tr_target.extend(train["target"].loc[val_ind])
    
    # Predict the test set
    test_pred = model.predict(dtest)
    test_predictions += test_pred / CFG.n_folds
    # Compute fold metric
    score = amex_metric(y_val, val_pred)
    print(f'Our fold {fold} CV score is {score}')
    del x_train, x_val, y_train, y_val, dtrain, dtest ,dvalid
    gc.collect()
    
# Compute out of folds metric
score = amex_metric(train[CFG.target], oof_predictions)
print(f'Our out of folds CV score is {score}')


# Create a dataframe to store test prediction
test_df = pd.DataFrame({'customer_ID': test['customer_ID'], 'prediction': test_predictions})
# test_df.to_csv(f'{CFG.output_dir}test_{CFG.model}_{score}_baseline_{CFG.n_folds}fold_seed{CFG.seed}.csv', index = False)
test_df.to_csv(f'{CFG.output_dir}test_{CFG.ver}_{CFG.model}_{score}_{CFG.n_folds}fold_seed{CFG.seed}.csv', index = False)


dic_oof = {
    "customer_ID":cids,
    "target":tr_target,
    "tabnet_oot":oof_predictions
}

# Create a dataframe to store out of folds predictions
oof_df = pd.DataFrame(dic_oof)
# oof_df = pd.DataFrame({'customer_ID': train['customer_ID'], 'target': train[CFG.target], 'prediction': oof_predictions})
oof_df.to_csv(f'{CFG.output_dir}oof_{CFG.ver}_{CFG.model}_{score}_{CFG.n_folds}fold_seed{CFG.seed}.csv', index = False)


# # Create a dataframe to store out of folds predictions
# oof_df = pd.DataFrame({'customer_ID': train['customer_ID'], 'target': train[CFG.target], 'prediction': oof_predictions})
# oof_df.to_csv(f'../output/Amex LGBM Dart CV 0.7977/oof_lgbm_{CFG.boosting_type}_baseline_{CFG.n_folds}fold_seed{CFG.seed}.csv', index = False)


# # Create a dataframe to store test prediction
# test_df = pd.DataFrame({'customer_ID': test['customer_ID'], 'prediction': test_predictions})
# test_df.to_csv(f'../output/Amex LGBM Dart CV 0.7977/test_lgbm_{CFG.boosting_type}_baseline_{CFG.n_folds}fold_seed{CFG.seed}.csv', index = False)
# Out:
#
# --------------------------------------------------
# Training fold 0 with 2011 features...
# [01:14:00] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0]	train-logloss:0.68726	train-amex:0.71600	valid-logloss:0.68729	valid-amex:0.70730
# [100]	train-logloss:0.37751	train-amex:0.77323	valid-logloss:0.38162	valid-amex:0.75923
# [200]	train-logloss:0.27994	train-amex:0.78541	valid-logloss:0.28740	valid-amex:0.76835
# [300]	train-logloss:0.24160	train-amex:0.79421	valid-logloss:0.25174	valid-amex:0.77346
# [400]	train-logloss:0.22432	train-amex:0.80162	valid-logloss:0.23684	valid-amex:0.77683
# [500]	train-logloss:0.21518	train-amex:0.80842	valid-logloss:0.22984	valid-amex:0.78093
# [600]	train-logloss:0.20929	train-amex:0.81416	valid-logloss:0.22608	valid-amex:0.78355
# [700]	train-logloss:0.20474	train-amex:0.82001	valid-logloss:0.22373	valid-amex:0.78558
# [800]	train-logloss:0.20100	train-amex:0.82492	valid-logloss:0.22210	valid-amex:0.78776
# [900]	train-logloss:0.19765	train-amex:0.82993	valid-logloss:0.22090	valid-amex:0.78982
# [1000]	train-logloss:0.19461	train-amex:0.83479	valid-logloss:0.21991	valid-amex:0.79096
# [1100]	train-logloss:0.19182	train-amex:0.83906	valid-logloss:0.21914	valid-amex:0.79204
# [1200]	train-logloss:0.18942	train-amex:0.84284	valid-logloss:0.21853	valid-amex:0.79214
# [1300]	train-logloss:0.18700	train-amex:0.84703	valid-logloss:0.21805	valid-amex:0.79308
# [1400]	train-logloss:0.18472	train-amex:0.85128	valid-logloss:0.21762	valid-amex:0.79394
# [1500]	train-logloss:0.18250	train-amex:0.85501	valid-logloss:0.21724	valid-amex:0.79436
# [1600]	train-logloss:0.18048	train-amex:0.85862	valid-logloss:0.21696	valid-amex:0.79442
# [1700]	train-logloss:0.17856	train-amex:0.86193	valid-logloss:0.21670	valid-amex:0.79466
# [1800]	train-logloss:0.17662	train-amex:0.86551	valid-logloss:0.21646	valid-amex:0.79573
# [1900]	train-logloss:0.17481	train-amex:0.86877	valid-logloss:0.21629	valid-amex:0.79587
# [2000]	train-logloss:0.17295	train-amex:0.87223	valid-logloss:0.21611	valid-amex:0.79646
# [2100]	train-logloss:0.17119	train-amex:0.87531	valid-logloss:0.21595	valid-amex:0.79660
# [2200]	train-logloss:0.16942	train-amex:0.87818	valid-logloss:0.21582	valid-amex:0.79652
# [2300]	train-logloss:0.16784	train-amex:0.88102	valid-logloss:0.21569	valid-amex:0.79663
# [2400]	train-logloss:0.16618	train-amex:0.88396	valid-logloss:0.21558	valid-amex:0.79719
# [2500]	train-logloss:0.16463	train-amex:0.88674	valid-logloss:0.21551	valid-amex:0.79707
# [2600]	train-logloss:0.16297	train-amex:0.88987	valid-logloss:0.21543	valid-amex:0.79743
# [2700]	train-logloss:0.16141	train-amex:0.89276	valid-logloss:0.21535	valid-amex:0.79718
# [2800]	train-logloss:0.15988	train-amex:0.89546	valid-logloss:0.21530	valid-amex:0.79752
# [2900]	train-logloss:0.15842	train-amex:0.89791	valid-logloss:0.21523	valid-amex:0.79724
# [3000]	train-logloss:0.15688	train-amex:0.90061	valid-logloss:0.21518	valid-amex:0.79762
# [3100]	train-logloss:0.15545	train-amex:0.90317	valid-logloss:0.21516	valid-amex:0.79737
# [3131]	train-logloss:0.15498	train-amex:0.90391	valid-logloss:0.21514	valid-amex:0.79744
# Our fold 0 CV score is 0.7972043263518211
#
# --------------------------------------------------
# Training fold 1 with 2011 features...
# [03:00:03] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0]	train-logloss:0.68727	train-amex:0.71666	valid-logloss:0.68729	valid-amex:0.70762
# [100]	train-logloss:0.37763	train-amex:0.77431	valid-logloss:0.38112	valid-amex:0.75496
# [200]	train-logloss:0.28003	train-amex:0.78601	valid-logloss:0.28677	valid-amex:0.76432
# [300]	train-logloss:0.24161	train-amex:0.79468	valid-logloss:0.25116	valid-amex:0.77086
# [400]	train-logloss:0.22426	train-amex:0.80217	valid-logloss:0.23629	valid-amex:0.77551
# [500]	train-logloss:0.21499	train-amex:0.80911	valid-logloss:0.22928	valid-amex:0.77996
# [600]	train-logloss:0.20915	train-amex:0.81479	valid-logloss:0.22558	valid-amex:0.78302
# [700]	train-logloss:0.20459	train-amex:0.82062	valid-logloss:0.22328	valid-amex:0.78612
# [800]	train-logloss:0.20067	train-amex:0.82647	valid-logloss:0.22175	valid-amex:0.78775
# [900]	train-logloss:0.19740	train-amex:0.83150	valid-logloss:0.22063	valid-amex:0.78833
# [1000]	train-logloss:0.19445	train-amex:0.83573	valid-logloss:0.21980	valid-amex:0.78952
# [1100]	train-logloss:0.19168	train-amex:0.83974	valid-logloss:0.21911	valid-amex:0.79044
# [1200]	train-logloss:0.18913	train-amex:0.84360	valid-logloss:0.21855	valid-amex:0.79161
# [1300]	train-logloss:0.18678	train-amex:0.84752	valid-logloss:0.21811	valid-amex:0.79229
# [1400]	train-logloss:0.18453	train-amex:0.85146	valid-logloss:0.21774	valid-amex:0.79298
# [1500]	train-logloss:0.18236	train-amex:0.85525	valid-logloss:0.21744	valid-amex:0.79363
# [1600]	train-logloss:0.18038	train-amex:0.85872	valid-logloss:0.21719	valid-amex:0.79397
# [1700]	train-logloss:0.17838	train-amex:0.86254	valid-logloss:0.21695	valid-amex:0.79445
# [1800]	train-logloss:0.17650	train-amex:0.86584	valid-logloss:0.21677	valid-amex:0.79493
# [1900]	train-logloss:0.17466	train-amex:0.86913	valid-logloss:0.21659	valid-amex:0.79497
# [2000]	train-logloss:0.17286	train-amex:0.87238	valid-logloss:0.21644	valid-amex:0.79517
# [2100]	train-logloss:0.17112	train-amex:0.87551	valid-logloss:0.21633	valid-amex:0.79532
# [2200]	train-logloss:0.16947	train-amex:0.87852	valid-logloss:0.21622	valid-amex:0.79502
# [2300]	train-logloss:0.16775	train-amex:0.88159	valid-logloss:0.21611	valid-amex:0.79468
# [2400]	train-logloss:0.16607	train-amex:0.88430	valid-logloss:0.21602	valid-amex:0.79437
# [2500]	train-logloss:0.16435	train-amex:0.88743	valid-logloss:0.21594	valid-amex:0.79407
# [2538]	train-logloss:0.16377	train-amex:0.88832	valid-logloss:0.21592	valid-amex:0.79412
# Our fold 1 CV score is 0.7937308690299768
#
# --------------------------------------------------
# Training fold 2 with 2011 features...
# [04:26:45] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0]	train-logloss:0.68727	train-amex:0.71819	valid-logloss:0.68724	valid-amex:0.70889
# [100]	train-logloss:0.37747	train-amex:0.77434	valid-logloss:0.38155	valid-amex:0.75698
# [200]	train-logloss:0.27976	train-amex:0.78651	valid-logloss:0.28747	valid-amex:0.76599
# [300]	train-logloss:0.24135	train-amex:0.79471	valid-logloss:0.25211	valid-amex:0.77103
# [400]	train-logloss:0.22406	train-amex:0.80236	valid-logloss:0.23739	valid-amex:0.77604
# [500]	train-logloss:0.21487	train-amex:0.80880	valid-logloss:0.23053	valid-amex:0.77871
# [600]	train-logloss:0.20905	train-amex:0.81466	valid-logloss:0.22690	valid-amex:0.78109
# [700]	train-logloss:0.20458	train-amex:0.82020	valid-logloss:0.22465	valid-amex:0.78329
# [800]	train-logloss:0.20081	train-amex:0.82596	valid-logloss:0.22306	valid-amex:0.78536
# [900]	train-logloss:0.19752	train-amex:0.83074	valid-logloss:0.22191	valid-amex:0.78707
# [1000]	train-logloss:0.19454	train-amex:0.83545	valid-logloss:0.22103	valid-amex:0.78797
# [1100]	train-logloss:0.19183	train-amex:0.83976	valid-logloss:0.22037	valid-amex:0.78941
# [1200]	train-logloss:0.18931	train-amex:0.84356	valid-logloss:0.21979	valid-amex:0.79020
# [1300]	train-logloss:0.18705	train-amex:0.84726	valid-logloss:0.21934	valid-amex:0.79025
# [1400]	train-logloss:0.18486	train-amex:0.85116	valid-logloss:0.21899	valid-amex:0.79054
# [1500]	train-logloss:0.18263	train-amex:0.85516	valid-logloss:0.21866	valid-amex:0.79120
# [1600]	train-logloss:0.18057	train-amex:0.85848	valid-logloss:0.21838	valid-amex:0.79155
# [1700]	train-logloss:0.17846	train-amex:0.86208	valid-logloss:0.21814	valid-amex:0.79175
# [1800]	train-logloss:0.17659	train-amex:0.86531	valid-logloss:0.21794	valid-amex:0.79234
# [1900]	train-logloss:0.17465	train-amex:0.86883	valid-logloss:0.21776	valid-amex:0.79249
# [2000]	train-logloss:0.17287	train-amex:0.87187	valid-logloss:0.21762	valid-amex:0.79247
# [2100]	train-logloss:0.17113	train-amex:0.87513	valid-logloss:0.21748	valid-amex:0.79330
# [2200]	train-logloss:0.16949	train-amex:0.87804	valid-logloss:0.21736	valid-amex:0.79367
# [2300]	train-logloss:0.16778	train-amex:0.88118	valid-logloss:0.21724	valid-amex:0.79403
# [2400]	train-logloss:0.16614	train-amex:0.88418	valid-logloss:0.21712	valid-amex:0.79428
# [2500]	train-logloss:0.16452	train-amex:0.88724	valid-logloss:0.21705	valid-amex:0.79448
# [2600]	train-logloss:0.16295	train-amex:0.89011	valid-logloss:0.21696	valid-amex:0.79409
# [2700]	train-logloss:0.16146	train-amex:0.89263	valid-logloss:0.21688	valid-amex:0.79405
# [2800]	train-logloss:0.15985	train-amex:0.89535	valid-logloss:0.21682	valid-amex:0.79448
# [2900]	train-logloss:0.15829	train-amex:0.89820	valid-logloss:0.21676	valid-amex:0.79435
# [2939]	train-logloss:0.15768	train-amex:0.89930	valid-logloss:0.21674	valid-amex:0.79417
# Our fold 2 CV score is 0.7939953922647724
#
# --------------------------------------------------
# Training fold 3 with 2011 features...
# [06:05:40] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0]	train-logloss:0.68726	train-amex:0.71656	valid-logloss:0.68729	valid-amex:0.71373
# [100]	train-logloss:0.37772	train-amex:0.77238	valid-logloss:0.38120	valid-amex:0.76213
# [200]	train-logloss:0.28011	train-amex:0.78465	valid-logloss:0.28667	valid-amex:0.77019
# [300]	train-logloss:0.24175	train-amex:0.79390	valid-logloss:0.25099	valid-amex:0.77565
# [400]	train-logloss:0.22435	train-amex:0.80181	valid-logloss:0.23599	valid-amex:0.77938
# [500]	train-logloss:0.21514	train-amex:0.80833	valid-logloss:0.22893	valid-amex:0.78210
# [600]	train-logloss:0.20938	train-amex:0.81428	valid-logloss:0.22524	valid-amex:0.78514
# [700]	train-logloss:0.20484	train-amex:0.82021	valid-logloss:0.22298	valid-amex:0.78718
# [800]	train-logloss:0.20099	train-amex:0.82590	valid-logloss:0.22141	valid-amex:0.78940
# [900]	train-logloss:0.19768	train-amex:0.83101	valid-logloss:0.22027	valid-amex:0.79041
# [1000]	train-logloss:0.19471	train-amex:0.83568	valid-logloss:0.21941	valid-amex:0.79145
# [1100]	train-logloss:0.19189	train-amex:0.84030	valid-logloss:0.21869	valid-amex:0.79290
# [1200]	train-logloss:0.18940	train-amex:0.84420	valid-logloss:0.21812	valid-amex:0.79340
# [1300]	train-logloss:0.18711	train-amex:0.84828	valid-logloss:0.21767	valid-amex:0.79430
# [1400]	train-logloss:0.18487	train-amex:0.85196	valid-logloss:0.21727	valid-amex:0.79435
# [1500]	train-logloss:0.18285	train-amex:0.85537	valid-logloss:0.21695	valid-amex:0.79452
# [1600]	train-logloss:0.18081	train-amex:0.85886	valid-logloss:0.21669	valid-amex:0.79453
# [1700]	train-logloss:0.17897	train-amex:0.86213	valid-logloss:0.21646	valid-amex:0.79509
# [1800]	train-logloss:0.17711	train-amex:0.86547	valid-logloss:0.21626	valid-amex:0.79501
# [1900]	train-logloss:0.17521	train-amex:0.86881	valid-logloss:0.21607	valid-amex:0.79505
# [2000]	train-logloss:0.17347	train-amex:0.87196	valid-logloss:0.21592	valid-amex:0.79515
# [2100]	train-logloss:0.17172	train-amex:0.87503	valid-logloss:0.21579	valid-amex:0.79513
# [2200]	train-logloss:0.17000	train-amex:0.87833	valid-logloss:0.21568	valid-amex:0.79565
# [2300]	train-logloss:0.16831	train-amex:0.88114	valid-logloss:0.21557	valid-amex:0.79600
# [2400]	train-logloss:0.16671	train-amex:0.88381	valid-logloss:0.21545	valid-amex:0.79614
# [2500]	train-logloss:0.16514	train-amex:0.88652	valid-logloss:0.21536	valid-amex:0.79622
# [2600]	train-logloss:0.16348	train-amex:0.88955	valid-logloss:0.21528	valid-amex:0.79606
# [2700]	train-logloss:0.16194	train-amex:0.89248	valid-logloss:0.21521	valid-amex:0.79606
# [2800]	train-logloss:0.16037	train-amex:0.89509	valid-logloss:0.21513	valid-amex:0.79632
# [2900]	train-logloss:0.15882	train-amex:0.89768	valid-logloss:0.21508	valid-amex:0.79678
# [3000]	train-logloss:0.15738	train-amex:0.90002	valid-logloss:0.21504	valid-amex:0.79665
# [3100]	train-logloss:0.15584	train-amex:0.90272	valid-logloss:0.21498	valid-amex:0.79660
# [3200]	train-logloss:0.15433	train-amex:0.90530	valid-logloss:0.21494	valid-amex:0.79683
# [3300]	train-logloss:0.15286	train-amex:0.90792	valid-logloss:0.21489	valid-amex:0.79708
# [3400]	train-logloss:0.15146	train-amex:0.91023	valid-logloss:0.21486	valid-amex:0.79673
# [3500]	train-logloss:0.15004	train-amex:0.91247	valid-logloss:0.21484	valid-amex:0.79682
# [3600]	train-logloss:0.14854	train-amex:0.91497	valid-logloss:0.21480	valid-amex:0.79654
# [3700]	train-logloss:0.14719	train-amex:0.91726	valid-logloss:0.21479	valid-amex:0.79670
# [3800]	train-logloss:0.14586	train-amex:0.91939	valid-logloss:0.21478	valid-amex:0.79653
# Our fold 3 CV score is 0.7963205844453567
#
# --------------------------------------------------
# Training fold 4 with 2011 features...
# [08:09:23] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0]	train-logloss:0.68728	train-amex:0.71784	valid-logloss:0.68727	valid-amex:0.70327
# [100]	train-logloss:0.37699	train-amex:0.77541	valid-logloss:0.38289	valid-amex:0.75190
# [200]	train-logloss:0.27924	train-amex:0.78763	valid-logloss:0.28932	valid-amex:0.75778
# [300]	train-logloss:0.24078	train-amex:0.79633	valid-logloss:0.25418	valid-amex:0.76349
# [400]	train-logloss:0.22343	train-amex:0.80411	valid-logloss:0.23957	valid-amex:0.76795
# [500]	train-logloss:0.21424	train-amex:0.81047	valid-logloss:0.23275	valid-amex:0.77267
# [600]	train-logloss:0.20849	train-amex:0.81627	valid-logloss:0.22914	valid-amex:0.77526
# [700]	train-logloss:0.20397	train-amex:0.82210	valid-logloss:0.22693	valid-amex:0.77821
# [800]	train-logloss:0.20012	train-amex:0.82731	valid-logloss:0.22535	valid-amex:0.78034
# [900]	train-logloss:0.19678	train-amex:0.83229	valid-logloss:0.22417	valid-amex:0.78167
# [1000]	train-logloss:0.19397	train-amex:0.83670	valid-logloss:0.22331	valid-amex:0.78304
# [1100]	train-logloss:0.19130	train-amex:0.84082	valid-logloss:0.22258	valid-amex:0.78372
# [1200]	train-logloss:0.18870	train-amex:0.84481	valid-logloss:0.22199	valid-amex:0.78467
# [1300]	train-logloss:0.18641	train-amex:0.84835	valid-logloss:0.22154	valid-amex:0.78506
# [1400]	train-logloss:0.18411	train-amex:0.85243	valid-logloss:0.22112	valid-amex:0.78547
# [1500]	train-logloss:0.18202	train-amex:0.85604	valid-logloss:0.22079	valid-amex:0.78537
# [1600]	train-logloss:0.18016	train-amex:0.85920	valid-logloss:0.22051	valid-amex:0.78598
# [1700]	train-logloss:0.17816	train-amex:0.86278	valid-logloss:0.22026	valid-amex:0.78666
# [1800]	train-logloss:0.17620	train-amex:0.86636	valid-logloss:0.22006	valid-amex:0.78650
# [1900]	train-logloss:0.17440	train-amex:0.86934	valid-logloss:0.21990	valid-amex:0.78694
# [2000]	train-logloss:0.17275	train-amex:0.87225	valid-logloss:0.21974	valid-amex:0.78694
# [2100]	train-logloss:0.17100	train-amex:0.87534	valid-logloss:0.21959	valid-amex:0.78754
# [2200]	train-logloss:0.16925	train-amex:0.87850	valid-logloss:0.21948	valid-amex:0.78735
# [2300]	train-logloss:0.16755	train-amex:0.88152	valid-logloss:0.21938	valid-amex:0.78743
# [2400]	train-logloss:0.16590	train-amex:0.88438	valid-logloss:0.21926	valid-amex:0.78710
# [2500]	train-logloss:0.16434	train-amex:0.88738	valid-logloss:0.21916	valid-amex:0.78762
# [2600]	train-logloss:0.16271	train-amex:0.89028	valid-logloss:0.21908	valid-amex:0.78754
# [2700]	train-logloss:0.16114	train-amex:0.89305	valid-logloss:0.21901	valid-amex:0.78774
# [2800]	train-logloss:0.15961	train-amex:0.89570	valid-logloss:0.21894	valid-amex:0.78777
# [2900]	train-logloss:0.15812	train-amex:0.89840	valid-logloss:0.21887	valid-amex:0.78799
# [3000]	train-logloss:0.15668	train-amex:0.90100	valid-logloss:0.21880	valid-amex:0.78839
# [3100]	train-logloss:0.15508	train-amex:0.90399	valid-logloss:0.21875	valid-amex:0.78829
# [3200]	train-logloss:0.15362	train-amex:0.90644	valid-logloss:0.21869	valid-amex:0.78884
# [3300]	train-logloss:0.15215	train-amex:0.90888	valid-logloss:0.21866	valid-amex:0.78879
# [3400]	train-logloss:0.15071	train-amex:0.91134	valid-logloss:0.21862	valid-amex:0.78904
# [3500]	train-logloss:0.14935	train-amex:0.91352	valid-logloss:0.21859	valid-amex:0.78880
# [3600]	train-logloss:0.14794	train-amex:0.91563	valid-logloss:0.21855	valid-amex:0.78903
# [3700]	train-logloss:0.14657	train-amex:0.91778	valid-logloss:0.21854	valid-amex:0.78878
# [3800]	train-logloss:0.14511	train-amex:0.92022	valid-logloss:0.21851	valid-amex:0.78907
# [3900]	train-logloss:0.14380	train-amex:0.92256	valid-logloss:0.21849	valid-amex:0.78923
# [4000]	train-logloss:0.14252	train-amex:0.92444	valid-logloss:0.21847	valid-amex:0.78937
# [4100]	train-logloss:0.14117	train-amex:0.92649	valid-logloss:0.21846	valid-amex:0.78889
# [4200]	train-logloss:0.13991	train-amex:0.92847	valid-logloss:0.21842	valid-amex:0.78929
# [4300]	train-logloss:0.13867	train-amex:0.93036	valid-logloss:0.21840	valid-amex:0.78928
# [4400]	train-logloss:0.13730	train-amex:0.93266	valid-logloss:0.21840	valid-amex:0.78891
# [4500]	train-logloss:0.13605	train-amex:0.93461	valid-logloss:0.21838	valid-amex:0.78881
# [4600]	train-logloss:0.13481	train-amex:0.93644	valid-logloss:0.21837	valid-amex:0.78905
# [4700]	train-logloss:0.13355	train-amex:0.93835	valid-logloss:0.21837	valid-amex:0.78878
# [4768]	train-logloss:0.13276	train-amex:0.93953	valid-logloss:0.21838	valid-amex:0.78866
# Our fold 4 CV score is 0.7884447010151892
# Our out of folds CV score is 0.793969281325366
