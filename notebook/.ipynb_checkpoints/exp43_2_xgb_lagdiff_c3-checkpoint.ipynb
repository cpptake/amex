# %% [markdown]
# # exp43
#
# lag_diffのXGB
#
#
# https://www.kaggle.com/code/ragnar123/amex-lgbm-dart-cv-0-7977

# %%
# ====================================================
# Library
# ====================================================
import gc
import warnings
warnings.filterwarnings('ignore')
import scipy as sp
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
from tqdm.auto import tqdm
import itertools

import lightgbm as lgb
import xgboost as xgb

# %%
print(xgb.__version__)
# Out:
# 1.5.0

# %%
# ====================================================
# Get the difference
# ====================================================
def get_difference(data, num_features):
    df1 = []
    customer_ids = []
    for customer_id, df in tqdm(data.groupby(['customer_ID'])):
        # Get the differences
        diff_df1 = df[num_features].diff(1).iloc[[-1]].values.astype(np.float32)
        # Append to lists
        df1.append(diff_df1)
        customer_ids.append(customer_id)
    # Concatenate
    df1 = np.concatenate(df1, axis = 0)
    # Transform to dataframe
    df1 = pd.DataFrame(df1, columns = [col + '_diff1' for col in df[num_features].columns])
    # Add customer id
    df1['customer_ID'] = customer_ids
    return df1

# ====================================================
# Read & preprocess data and save it to disk
# ====================================================
def read_preprocess_data():
    train = pd.read_parquet('/content/data/train.parquet')
    features = train.drop(['customer_ID', 'S_2'], axis = 1).columns.to_list()
    cat_features = [
        "B_30",
        "B_38",
        "D_114",
        "D_116",
        "D_117",
        "D_120",
        "D_126",
        "D_63",
        "D_64",
        "D_66",
        "D_68",
    ]
    num_features = [col for col in features if col not in cat_features]
    print('Starting training feature engineer...')
    train_num_agg = train.groupby("customer_ID")[num_features].agg(['mean', 'std', 'min', 'max', 'last'])
    train_num_agg.columns = ['_'.join(x) for x in train_num_agg.columns]
    train_num_agg.reset_index(inplace = True)
    train_cat_agg = train.groupby("customer_ID")[cat_features].agg(['count', 'last', 'nunique'])
    train_cat_agg.columns = ['_'.join(x) for x in train_cat_agg.columns]
    train_cat_agg.reset_index(inplace = True)
    train_labels = pd.read_csv('../input/amex-default-prediction/train_labels.csv')
    # Transform float64 columns to float32
    cols = list(train_num_agg.dtypes[train_num_agg.dtypes == 'float64'].index)
    for col in tqdm(cols):
        train_num_agg[col] = train_num_agg[col].astype(np.float32)
    # Transform int64 columns to int32
    cols = list(train_cat_agg.dtypes[train_cat_agg.dtypes == 'int64'].index)
    for col in tqdm(cols):
        train_cat_agg[col] = train_cat_agg[col].astype(np.int32)
    # Get the difference
    train_diff = get_difference(train, num_features)
    train = train_num_agg.merge(train_cat_agg, how = 'inner', on = 'customer_ID').merge(train_diff, how = 'inner', on = 'customer_ID').merge(train_labels, how = 'inner', on = 'customer_ID')
    del train_num_agg, train_cat_agg, train_diff
    gc.collect()
    test = pd.read_parquet('../input/amex-fe/test_fe.parquet')
    print('Starting test feature engineer...')
    test_num_agg = test.groupby("customer_ID")[num_features].agg(['mean', 'std', 'min', 'max', 'last'])
    test_num_agg.columns = ['_'.join(x) for x in test_num_agg.columns]
    test_num_agg.reset_index(inplace = True)
    test_cat_agg = test.groupby("customer_ID")[cat_features].agg(['count', 'last', 'nunique'])
    test_cat_agg.columns = ['_'.join(x) for x in test_cat_agg.columns]
    test_cat_agg.reset_index(inplace = True)
    # Transform float64 columns to float32
    cols = list(test_num_agg.dtypes[test_num_agg.dtypes == 'float64'].index)
    for col in tqdm(cols):
        test_num_agg[col] = test_num_agg[col].astype(np.float32)
    # Transform int64 columns to int32
    cols = list(test_cat_agg.dtypes[test_cat_agg.dtypes == 'int64'].index)
    for col in tqdm(cols):
        test_cat_agg[col] = test_cat_agg[col].astype(np.int32)
    # Get the difference
    test_diff = get_difference(test, num_features)
    test = test_num_agg.merge(test_cat_agg, how = 'inner', on = 'customer_ID').merge(test_diff, how = 'inner', on = 'customer_ID')
    del test_num_agg, test_cat_agg, test_diff
    gc.collect()
    # Save files to disk
    train.to_parquet('../input/amex-fe/train_fe.parquet')
    test.to_parquet('../input/amex-fe/test_fe.parquet')

# Read & Preprocess Data
read_preprocess_data()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27124\217815574.py in <module>
#      86
#      87 # Read & Preprocess Data
# ---> 88 read_preprocess_data()
#
# ~\AppData\Local\Temp\ipykernel_27124\217815574.py in read_preprocess_data()
#      23 # ====================================================
#      24 def read_preprocess_data():
# ---> 25     train = pd.read_parquet('/content/data/train.parquet')
#      26     features = train.drop(['customer_ID', 'S_2'], axis = 1).columns.to_list()
#      27     cat_features = [
#
# ~\anaconda3\envs\amex\lib\site-packages\pandas\io\parquet.py in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, **kwargs)
#     498         storage_options=storage_options,
#     499         use_nullable_dtypes=use_nullable_dtypes,
# --> 500         **kwargs,
#     501     )
#
# ~\anaconda3\envs\amex\lib\site-packages\pandas\io\parquet.py in read(self, path, columns, use_nullable_dtypes, storage_options, **kwargs)
#     234             kwargs.pop("filesystem", None),
#     235             storage_options=storage_options,
# --> 236             mode="rb",
#     237         )
#     238         try:
#
# ~\anaconda3\envs\amex\lib\site-packages\pandas\io\parquet.py in _get_path_or_handle(path, fs, storage_options, mode, is_dir)
#     100         # this branch is used for example when reading from non-fsspec URLs
#     101         handles = get_handle(
# --> 102             path_or_handle, mode, is_text=False, storage_options=storage_options
#     103         )
#     104         fs = None
#
# ~\anaconda3\envs\amex\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     709         else:
#     710             # Binary mode
# --> 711             handle = open(handle, ioargs.mode)
#     712         handles.append(handle)
#     713
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/data/train.parquet'

# %% [markdown]
# # Training & Inference

# %%
# ====================================================
# Library
# ====================================================
import os
import gc
import warnings
warnings.filterwarnings('ignore')
import random
import scipy as sp
import numpy as np
import pandas as pd
import joblib
import itertools
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
from tqdm.auto import tqdm
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.preprocessing import LabelEncoder
import lightgbm as lgb
from itertools import combinations

import pickle

# ====================================================
# Configurations
# ====================================================
class CFG:
    
    
    # input_dir = '../feature/exp35_lagdiff/'
    input_dir = '../feature/exp03_amex-fe/'
    output_dir = '../output/exp43_xgb_lagdiff_c3_hypar/'
    seed = 42
    n_folds = 5
    target = 'target'
    boosting_type = 'dart'
    metric = 'binary_logloss'
    model = "xgb"
    ver ="exp43"

# ====================================================
# Seed everything
# ====================================================
def seed_everything(seed):
    random.seed(seed)
    np.random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)

# ====================================================
# Read data
# ====================================================
# def read_data():
#     train = pd.read_parquet(CFG.input_dir + 'train_diff.parquet')
#     test = pd.read_parquet(CFG.input_dir + 'test_diff.parquet')
#     return train, test

def read_data():
    train = pd.read_parquet(CFG.input_dir + 'train_fe_plus_plus.parquet')
    test = pd.read_parquet(CFG.input_dir + 'test_fe_plus_plus.parquet')
    return train, test

# ====================================================
# Amex metric
# ====================================================
def amex_metric(y_true, y_pred):
    labels = np.transpose(np.array([y_true, y_pred]))
    labels = labels[labels[:, 1].argsort()[::-1]]
    weights = np.where(labels[:,0]==0, 20, 1)
    cut_vals = labels[np.cumsum(weights) <= int(0.04 * np.sum(weights))]
    top_four = np.sum(cut_vals[:,0]) / np.sum(labels[:,0])
    gini = [0,0]
    for i in [1,0]:
        labels = np.transpose(np.array([y_true, y_pred]))
        labels = labels[labels[:, i].argsort()[::-1]]
        weight = np.where(labels[:,0]==0, 20, 1)
        weight_random = np.cumsum(weight / np.sum(weight))
        total_pos = np.sum(labels[:, 0] *  weight)
        cum_pos_found = np.cumsum(labels[:, 0] * weight)
        lorentz = cum_pos_found / total_pos
        gini[i] = np.sum((lorentz - weight_random) * weight)
    return 0.5 * (gini[1]/gini[0] + top_four)

# ====================================================
# LGBM amex metric
# ====================================================
def lgb_amex_metric(y_pred, y_true):
    y_true = y_true.get_label()
    return 'amex_metric', amex_metric(y_true, y_pred), True

# %%
seed_everything(CFG.seed)


train = pd.read_parquet('../feature/exp38_lagdiff_c3/train_lagdiff_c3.parquet')
test = pd.read_parquet('../feature/exp38_lagdiff_c3/test_lagdiff_c3.parquet')


# OneDrive/デスクトップ/code/AMEX/feature/exp38_lagdiff_c3/test_lagdiff_c3.parquet

# train = pd.read_parquet('../feature/exp35_lagdiff/train_lagdiff.parquet')
# test = pd.read_parquet('../feature/exp35_lagdiff/test_lagdiff.parquet')

# train, test = read_data()

# train_c3 = pd.read_pickle('../feature/exp18_4_tsfresh/train_c3.pkl')
# test_c3 = pd.read_pickle('../feature/exp18_4_tsfresh/test_c3.pkl')

# train = train.merge(train_c3,on = "customer_ID",how = "left")
# test = test.merge(test_c3,on = "customer_ID",how = "left")

# del train_c3,test_c3
# gc.collect

# print(train.shape)
# print(test.shape)

# %%
def xgb_amex(y_pred, y_true):
    return 'amex', amex_metric_np(y_pred,y_true.get_label())


def amex_metric_np(preds: np.ndarray, target: np.ndarray) -> float:
    indices = np.argsort(preds)[::-1]
    preds, target = preds[indices], target[indices]

    weight = 20.0 - target * 19.0
    cum_norm_weight = (weight / weight.sum()).cumsum()
    four_pct_mask = cum_norm_weight <= 0.04
    d = np.sum(target[four_pct_mask]) / np.sum(target)

    weighted_target = target * weight
    lorentz = (weighted_target / weighted_target.sum()).cumsum()
    gini = ((lorentz - cum_norm_weight) * weight).sum()

    n_pos = np.sum(target)
    n_neg = target.shape[0] - n_pos
    gini_max = 10 * n_neg * (n_pos + 20 * n_neg - 19) / (n_pos + 20 * n_neg)

    g = gini / gini_max
    return 0.5 * (g + d)

# %%
train.fillna(value=0, inplace=True)
test.fillna(value=0, inplace=True)

## infを含むデータを外れ値（－１００００）に置換
train = train.replace([np.inf, -np.inf],100000000000)
test = test.replace([np.inf, -np.inf],100000000000)

# %%
cat_features = [
    "B_30",
    "B_38",
    "D_114",
    "D_116",
    "D_117",
    "D_120",
    "D_126",
    "D_63",
    "D_64",
    "D_66",
    "D_68"
]

# kmeans_list = ["kmeans pred 2","kmeans pred 3","kmeans pred 4"]

cat_features = [f"{cf}_last" for cf in cat_features]
# cat_features.extend(kmeans_list)

# for cat_col in cat_features:
# #     print(cat_col)
#     encoder = LabelEncoder()
#     train[cat_col] = encoder.fit_transform(train[cat_col])
#     test[cat_col] = encoder.transform(test[cat_col])


features = [col for col in train.columns if col not in ['customer_ID', CFG.target]]

xgb_parameters={
        'max_depth': 9,#7 # optuna 9
        'eta': 0.03,
        'subsample': 0.88,
        'colsample_bytree': 0.5,
        'objective': 'binary:logistic',
        'learning_rate' : 0.008971755769136095,#0.026582608139330333
        'tree_method': 'hist',#gpu_hist
        # 'predictor': 'gpu_predictor',
        'random_state': 42,
        'gamma': 1.5,
        'min_child_weight': 19,#8 # optuna 19
        'lambda': 70,
    }

# Create a numpy array to store test predictions
test_predictions = np.zeros(len(test))
# Create a numpy array to store out of folds predictions
oof_predictions = np.zeros(len(train))

cids = []
tr_target = []

# epoch = [10000,7500,7500,8500,10500]

kfold = StratifiedKFold(n_splits = CFG.n_folds, shuffle = True, random_state = CFG.seed)
for fold, (trn_ind, val_ind) in enumerate(kfold.split(train, train[CFG.target])):
    print(' ')
    print('-'*50)
    print(f'Training fold {fold} with {len(features)} features...')
    x_train, x_val = train[features].iloc[trn_ind], train[features].iloc[val_ind]
    y_train, y_val = train[CFG.target].iloc[trn_ind], train[CFG.target].iloc[val_ind]
    
    dtrain = xgb.DMatrix(data=x_train, label=y_train)
    dvalid = xgb.DMatrix(data=x_val, label=y_val)
    dtest = xgb.DMatrix(data=test[features])
    
#     des = DartEarlyStopping("valid_1", CFG.metric, 1000)
  
    model = xgb.train(
            xgb_parameters,
            dtrain=dtrain,
            num_boost_round=9999,#9999
            evals=[(dtrain, "train"), (dvalid, "valid")],
            early_stopping_rounds=500,
            feval=xgb_amex,
            maximize=True,
            verbose_eval=100
        )
    
    
    # Save best model
    model.save_model(f'{CFG.output_dir}{CFG.model}_{CFG.ver}_{CFG.boosting_type}_fold{fold}_seed{CFG.seed}.xgb')
#     joblib.dump(model, f'{CFG.output_dir}lgbm_{CFG.boosting_type}_fold{fold}_seed{CFG.seed}.pkl')
    # Predict validation
    val_pred = model.predict(dvalid)
    # Add to out of folds array
    oof_predictions[val_ind] = val_pred
    
    cids.extend(train["customer_ID"].loc[val_ind])
    tr_target.extend(train["target"].loc[val_ind])
    
    # Predict the test set
    test_pred = model.predict(dtest)
    test_predictions += test_pred / CFG.n_folds
    # Compute fold metric
    score = amex_metric(y_val, val_pred)
    print(f'Our fold {fold} CV score is {score}')
    del x_train, x_val, y_train, y_val, dtrain, dtest ,dvalid
    gc.collect()
    
# Compute out of folds metric
score = amex_metric(train[CFG.target], oof_predictions)
print(f'Our out of folds CV score is {score}')


# Create a dataframe to store test prediction
test_df = pd.DataFrame({'customer_ID': test['customer_ID'], 'prediction': test_predictions})
# test_df.to_csv(f'{CFG.output_dir}test_{CFG.model}_{score}_baseline_{CFG.n_folds}fold_seed{CFG.seed}.csv', index = False)
test_df.to_csv(f'{CFG.output_dir}test_{CFG.ver}_{CFG.model}_{score}_{CFG.n_folds}fold_seed{CFG.seed}.csv', index = False)


dic_oof = {
    "customer_ID":cids,
    "target":tr_target,
    "tabnet_oot":oof_predictions
}

# Create a dataframe to store out of folds predictions
oof_df = pd.DataFrame(dic_oof)
# oof_df = pd.DataFrame({'customer_ID': train['customer_ID'], 'target': train[CFG.target], 'prediction': oof_predictions})
oof_df.to_csv(f'{CFG.output_dir}oof_{CFG.ver}_{CFG.model}_{score}_{CFG.n_folds}fold_seed{CFG.seed}.csv', index = False)


# # Create a dataframe to store out of folds predictions
# oof_df = pd.DataFrame({'customer_ID': train['customer_ID'], 'target': train[CFG.target], 'prediction': oof_predictions})
# oof_df.to_csv(f'../output/Amex LGBM Dart CV 0.7977/oof_lgbm_{CFG.boosting_type}_baseline_{CFG.n_folds}fold_seed{CFG.seed}.csv', index = False)


# # Create a dataframe to store test prediction
# test_df = pd.DataFrame({'customer_ID': test['customer_ID'], 'prediction': test_predictions})
# test_df.to_csv(f'../output/Amex LGBM Dart CV 0.7977/test_lgbm_{CFG.boosting_type}_baseline_{CFG.n_folds}fold_seed{CFG.seed}.csv', index = False)
# Out:
#
# --------------------------------------------------
# Training fold 0 with 2011 features...
# [00:59:05] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0]	train-logloss:0.67585	train-amex:0.71588	valid-logloss:0.67583	valid-amex:0.71084
# [100]	train-logloss:0.24221	train-amex:0.79402	valid-logloss:0.25068	valid-amex:0.77464
# [200]	train-logloss:0.21005	train-amex:0.81276	valid-logloss:0.22493	valid-amex:0.78448
# [300]	train-logloss:0.19847	train-amex:0.82856	valid-logloss:0.21963	valid-amex:0.79031
# [400]	train-logloss:0.19017	train-amex:0.84189	valid-logloss:0.21726	valid-amex:0.79351
# [500]	train-logloss:0.18366	train-amex:0.85314	valid-logloss:0.21607	valid-amex:0.79546
# [600]	train-logloss:0.17777	train-amex:0.86357	valid-logloss:0.21538	valid-amex:0.79678
# [700]	train-logloss:0.17267	train-amex:0.87261	valid-logloss:0.21484	valid-amex:0.79768
# [800]	train-logloss:0.16780	train-amex:0.88139	valid-logloss:0.21445	valid-amex:0.79829
# [900]	train-logloss:0.16314	train-amex:0.88941	valid-logloss:0.21420	valid-amex:0.79865
# [1000]	train-logloss:0.15838	train-amex:0.89818	valid-logloss:0.21402	valid-amex:0.79906
# [1100]	train-logloss:0.15402	train-amex:0.90549	valid-logloss:0.21387	valid-amex:0.79940
# [1200]	train-logloss:0.15016	train-amex:0.91187	valid-logloss:0.21376	valid-amex:0.79942
# [1300]	train-logloss:0.14606	train-amex:0.91884	valid-logloss:0.21370	valid-amex:0.79971
# [1400]	train-logloss:0.14209	train-amex:0.92552	valid-logloss:0.21369	valid-amex:0.79937
# [1500]	train-logloss:0.13844	train-amex:0.93124	valid-logloss:0.21365	valid-amex:0.79982
# [1600]	train-logloss:0.13481	train-amex:0.93686	valid-logloss:0.21369	valid-amex:0.79946
# [1700]	train-logloss:0.13128	train-amex:0.94205	valid-logloss:0.21369	valid-amex:0.79958
# [1800]	train-logloss:0.12769	train-amex:0.94720	valid-logloss:0.21375	valid-amex:0.79980
# [1900]	train-logloss:0.12450	train-amex:0.95167	valid-logloss:0.21376	valid-amex:0.79947
# [2000]	train-logloss:0.12100	train-amex:0.95603	valid-logloss:0.21376	valid-amex:0.79983
# [2100]	train-logloss:0.11799	train-amex:0.95973	valid-logloss:0.21380	valid-amex:0.79983
# [2200]	train-logloss:0.11493	train-amex:0.96348	valid-logloss:0.21384	valid-amex:0.79983
# [2300]	train-logloss:0.11193	train-amex:0.96692	valid-logloss:0.21387	valid-amex:0.80018
# [2400]	train-logloss:0.10912	train-amex:0.96975	valid-logloss:0.21390	valid-amex:0.80021
# [2500]	train-logloss:0.10634	train-amex:0.97249	valid-logloss:0.21398	valid-amex:0.80006
# [2600]	train-logloss:0.10367	train-amex:0.97503	valid-logloss:0.21405	valid-amex:0.80021
# [2700]	train-logloss:0.10111	train-amex:0.97723	valid-logloss:0.21412	valid-amex:0.79985
# [2800]	train-logloss:0.09863	train-amex:0.97946	valid-logloss:0.21418	valid-amex:0.80045
# [2900]	train-logloss:0.09631	train-amex:0.98124	valid-logloss:0.21428	valid-amex:0.80030
# [3000]	train-logloss:0.09397	train-amex:0.98297	valid-logloss:0.21432	valid-amex:0.80027
# [3100]	train-logloss:0.09175	train-amex:0.98455	valid-logloss:0.21445	valid-amex:0.80043
# [3200]	train-logloss:0.08950	train-amex:0.98595	valid-logloss:0.21454	valid-amex:0.80025
# [3300]	train-logloss:0.08750	train-amex:0.98720	valid-logloss:0.21472	valid-amex:0.80019
# [3400]	train-logloss:0.08542	train-amex:0.98848	valid-logloss:0.21489	valid-amex:0.79998
# [3500]	train-logloss:0.08346	train-amex:0.98940	valid-logloss:0.21500	valid-amex:0.79988
# [3523]	train-logloss:0.08300	train-amex:0.98965	valid-logloss:0.21503	valid-amex:0.80019
# Our fold 0 CV score is 0.7999545382393319
#
# --------------------------------------------------
# Training fold 1 with 2011 features...
# [02:55:03] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0]	train-logloss:0.67583	train-amex:0.71575	valid-logloss:0.67585	valid-amex:0.70868
# [100]	train-logloss:0.24169	train-amex:0.79438	valid-logloss:0.25246	valid-amex:0.76742
# [200]	train-logloss:0.20931	train-amex:0.81468	valid-logloss:0.22738	valid-amex:0.77915
# [300]	train-logloss:0.19784	train-amex:0.83051	valid-logloss:0.22259	valid-amex:0.78399
# [400]	train-logloss:0.18995	train-amex:0.84257	valid-logloss:0.22057	valid-amex:0.78662
# [500]	train-logloss:0.18309	train-amex:0.85386	valid-logloss:0.21941	valid-amex:0.78714
# [600]	train-logloss:0.17717	train-amex:0.86419	valid-logloss:0.21881	valid-amex:0.78843
# [700]	train-logloss:0.17199	train-amex:0.87329	valid-logloss:0.21842	valid-amex:0.78941
# [800]	train-logloss:0.16690	train-amex:0.88242	valid-logloss:0.21814	valid-amex:0.79011
# [900]	train-logloss:0.16197	train-amex:0.89116	valid-logloss:0.21796	valid-amex:0.79026
# [1000]	train-logloss:0.15729	train-amex:0.89921	valid-logloss:0.21782	valid-amex:0.79120
# [1100]	train-logloss:0.15296	train-amex:0.90660	valid-logloss:0.21771	valid-amex:0.79167
# [1200]	train-logloss:0.14889	train-amex:0.91385	valid-logloss:0.21768	valid-amex:0.79167
# [1300]	train-logloss:0.14495	train-amex:0.92039	valid-logloss:0.21763	valid-amex:0.79180
# [1400]	train-logloss:0.14089	train-amex:0.92662	valid-logloss:0.21759	valid-amex:0.79198
# [1500]	train-logloss:0.13700	train-amex:0.93298	valid-logloss:0.21758	valid-amex:0.79198
# [1600]	train-logloss:0.13336	train-amex:0.93868	valid-logloss:0.21758	valid-amex:0.79190
# [1700]	train-logloss:0.12982	train-amex:0.94380	valid-logloss:0.21756	valid-amex:0.79103
# [1800]	train-logloss:0.12638	train-amex:0.94880	valid-logloss:0.21757	valid-amex:0.79142
# [1900]	train-logloss:0.12312	train-amex:0.95301	valid-logloss:0.21760	valid-amex:0.79186
# [1936]	train-logloss:0.12203	train-amex:0.95435	valid-logloss:0.21760	valid-amex:0.79193
# Our fold 1 CV score is 0.7916873377781166
#
# --------------------------------------------------
# Training fold 2 with 2011 features...
# [03:58:45] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0]	train-logloss:0.67580	train-amex:0.71614	valid-logloss:0.67586	valid-amex:0.70829
# [100]	train-logloss:0.24155	train-amex:0.79433	valid-logloss:0.25295	valid-amex:0.77163
# [200]	train-logloss:0.20922	train-amex:0.81397	valid-logloss:0.22753	valid-amex:0.78205
# [300]	train-logloss:0.19773	train-amex:0.82978	valid-logloss:0.22247	valid-amex:0.78837
# [400]	train-logloss:0.18965	train-amex:0.84292	valid-logloss:0.22029	valid-amex:0.79205
# [500]	train-logloss:0.18287	train-amex:0.85403	valid-logloss:0.21910	valid-amex:0.79420
# [600]	train-logloss:0.17683	train-amex:0.86485	valid-logloss:0.21843	valid-amex:0.79437
# [700]	train-logloss:0.17172	train-amex:0.87381	valid-logloss:0.21792	valid-amex:0.79482
# [800]	train-logloss:0.16690	train-amex:0.88228	valid-logloss:0.21764	valid-amex:0.79553
# [900]	train-logloss:0.16223	train-amex:0.89114	valid-logloss:0.21736	valid-amex:0.79590
# [1000]	train-logloss:0.15740	train-amex:0.89938	valid-logloss:0.21713	valid-amex:0.79600
# [1100]	train-logloss:0.15331	train-amex:0.90633	valid-logloss:0.21699	valid-amex:0.79618
# [1200]	train-logloss:0.14885	train-amex:0.91379	valid-logloss:0.21689	valid-amex:0.79685
# [1300]	train-logloss:0.14486	train-amex:0.92066	valid-logloss:0.21683	valid-amex:0.79686
# [1400]	train-logloss:0.14108	train-amex:0.92685	valid-logloss:0.21677	valid-amex:0.79678
# [1500]	train-logloss:0.13714	train-amex:0.93303	valid-logloss:0.21679	valid-amex:0.79674
# [1600]	train-logloss:0.13359	train-amex:0.93817	valid-logloss:0.21679	valid-amex:0.79686
# [1700]	train-logloss:0.13005	train-amex:0.94350	valid-logloss:0.21672	valid-amex:0.79723
# [1800]	train-logloss:0.12647	train-amex:0.94857	valid-logloss:0.21670	valid-amex:0.79702
# [1900]	train-logloss:0.12351	train-amex:0.95247	valid-logloss:0.21675	valid-amex:0.79737
# [2000]	train-logloss:0.12019	train-amex:0.95668	valid-logloss:0.21675	valid-amex:0.79712
# [2100]	train-logloss:0.11701	train-amex:0.96070	valid-logloss:0.21678	valid-amex:0.79748
# [2200]	train-logloss:0.11416	train-amex:0.96401	valid-logloss:0.21680	valid-amex:0.79751
# [2300]	train-logloss:0.11124	train-amex:0.96725	valid-logloss:0.21691	valid-amex:0.79737
# [2400]	train-logloss:0.10833	train-amex:0.97038	valid-logloss:0.21698	valid-amex:0.79714
# [2500]	train-logloss:0.10569	train-amex:0.97307	valid-logloss:0.21709	valid-amex:0.79702
# [2600]	train-logloss:0.10284	train-amex:0.97566	valid-logloss:0.21714	valid-amex:0.79762
# [2700]	train-logloss:0.10038	train-amex:0.97780	valid-logloss:0.21722	valid-amex:0.79720
# [2800]	train-logloss:0.09800	train-amex:0.97979	valid-logloss:0.21733	valid-amex:0.79680
# [2900]	train-logloss:0.09553	train-amex:0.98180	valid-logloss:0.21742	valid-amex:0.79758
# [3000]	train-logloss:0.09308	train-amex:0.98351	valid-logloss:0.21751	valid-amex:0.79718
# [3100]	train-logloss:0.09081	train-amex:0.98498	valid-logloss:0.21760	valid-amex:0.79692
# [3139]	train-logloss:0.09001	train-amex:0.98557	valid-logloss:0.21764	valid-amex:0.79726
# Our fold 2 CV score is 0.7970582360684505
#
# --------------------------------------------------
# Training fold 3 with 2011 features...
# [05:42:02] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0]	train-logloss:0.67582	train-amex:0.71600	valid-logloss:0.67594	valid-amex:0.70480
# [100]	train-logloss:0.24137	train-amex:0.79493	valid-logloss:0.25384	valid-amex:0.76704
# [200]	train-logloss:0.20899	train-amex:0.81482	valid-logloss:0.22855	valid-amex:0.77661
# [300]	train-logloss:0.19747	train-amex:0.83043	valid-logloss:0.22359	valid-amex:0.78236
# [400]	train-logloss:0.18928	train-amex:0.84381	valid-logloss:0.22148	valid-amex:0.78618
# [500]	train-logloss:0.18258	train-amex:0.85472	valid-logloss:0.22037	valid-amex:0.78774
# [600]	train-logloss:0.17664	train-amex:0.86511	valid-logloss:0.21963	valid-amex:0.78872
# [700]	train-logloss:0.17157	train-amex:0.87433	valid-logloss:0.21914	valid-amex:0.78939
# [800]	train-logloss:0.16661	train-amex:0.88310	valid-logloss:0.21887	valid-amex:0.78958
# [900]	train-logloss:0.16166	train-amex:0.89201	valid-logloss:0.21864	valid-amex:0.79019
# [1000]	train-logloss:0.15683	train-amex:0.90042	valid-logloss:0.21851	valid-amex:0.79069
# [1100]	train-logloss:0.15233	train-amex:0.90795	valid-logloss:0.21842	valid-amex:0.79008
# [1200]	train-logloss:0.14804	train-amex:0.91526	valid-logloss:0.21828	valid-amex:0.79052
# [1300]	train-logloss:0.14413	train-amex:0.92181	valid-logloss:0.21823	valid-amex:0.79075
# [1400]	train-logloss:0.14031	train-amex:0.92793	valid-logloss:0.21819	valid-amex:0.79044
# [1500]	train-logloss:0.13682	train-amex:0.93314	valid-logloss:0.21813	valid-amex:0.79043
# [1600]	train-logloss:0.13326	train-amex:0.93855	valid-logloss:0.21812	valid-amex:0.78980
# [1698]	train-logloss:0.12960	train-amex:0.94416	valid-logloss:0.21816	valid-amex:0.78941
# Our fold 3 CV score is 0.7891935469907206
#
# --------------------------------------------------
# Training fold 4 with 2011 features...
# [06:37:50] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0]	train-logloss:0.67585	train-amex:0.71428	valid-logloss:0.67586	valid-amex:0.70849
# [100]	train-logloss:0.24202	train-amex:0.79419	valid-logloss:0.25166	valid-amex:0.77243
# [200]	train-logloss:0.20974	train-amex:0.81378	valid-logloss:0.22590	valid-amex:0.78307
# [300]	train-logloss:0.19820	train-amex:0.82915	valid-logloss:0.22082	valid-amex:0.78719
# [400]	train-logloss:0.19021	train-amex:0.84206	valid-logloss:0.21864	valid-amex:0.79053
# [500]	train-logloss:0.18342	train-amex:0.85312	valid-logloss:0.21744	valid-amex:0.79170
# [600]	train-logloss:0.17781	train-amex:0.86279	valid-logloss:0.21672	valid-amex:0.79243
# [700]	train-logloss:0.17243	train-amex:0.87235	valid-logloss:0.21623	valid-amex:0.79344
# [800]	train-logloss:0.16753	train-amex:0.88135	valid-logloss:0.21590	valid-amex:0.79380
# [900]	train-logloss:0.16306	train-amex:0.88940	valid-logloss:0.21564	valid-amex:0.79427
# [1000]	train-logloss:0.15835	train-amex:0.89763	valid-logloss:0.21546	valid-amex:0.79454
# [1100]	train-logloss:0.15387	train-amex:0.90538	valid-logloss:0.21533	valid-amex:0.79525
# [1200]	train-logloss:0.14977	train-amex:0.91207	valid-logloss:0.21523	valid-amex:0.79606
# [1300]	train-logloss:0.14576	train-amex:0.91874	valid-logloss:0.21514	valid-amex:0.79597
# [1400]	train-logloss:0.14157	train-amex:0.92586	valid-logloss:0.21507	valid-amex:0.79594
# [1500]	train-logloss:0.13796	train-amex:0.93183	valid-logloss:0.21502	valid-amex:0.79641
# [1600]	train-logloss:0.13432	train-amex:0.93768	valid-logloss:0.21498	valid-amex:0.79651
# [1700]	train-logloss:0.13094	train-amex:0.94274	valid-logloss:0.21499	valid-amex:0.79694
# [1800]	train-logloss:0.12745	train-amex:0.94743	valid-logloss:0.21496	valid-amex:0.79645
# [1900]	train-logloss:0.12426	train-amex:0.95184	valid-logloss:0.21496	valid-amex:0.79606
# [2000]	train-logloss:0.12101	train-amex:0.95608	valid-logloss:0.21500	valid-amex:0.79617
# [2100]	train-logloss:0.11804	train-amex:0.95944	valid-logloss:0.21506	valid-amex:0.79604
# [2196]	train-logloss:0.11510	train-amex:0.96307	valid-logloss:0.21511	valid-amex:0.79663
# Our fold 4 CV score is 0.7963952325087646
# Our out of folds CV score is 0.7947459791855336
